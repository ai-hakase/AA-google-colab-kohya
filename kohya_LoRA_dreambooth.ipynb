# %% [markdown]
# <a href="https://colab.research.google.com/github/koya-jp/AA-google-colab-kohya/blob/master/kohya_LoRA_dreambooth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![visitors](https://visitor-badge.glitch.me/badge?page_id=linaqruf.lora-dreambooth) [![](https://dcbadge.vercel.app/api/shield/850007095775723532?style=flat)](https://lookup.guru/850007095775723532) [![ko-fi](https://img.shields.io/badge/Support%20me%20on%20Ko--fi-F16061?logo=ko-fi&logoColor=white&style=flat)](https://ko-fi.com/linaqruf) <a href="https://saweria.co/linaqruf"><img alt="Saweria" src="https://img.shields.io/badge/Saweria-7B3F00?style=flat&logo=ko-fi&logoColor=white"/></a>
#
# # **Kohya LoRA Dreambooth**
# A Colab Notebook For LoRA Training (Dreambooth Method)

# %% [markdown]
# # I. Install Kohya Trainer

# %%
#　参考：　https://indoortimes.net/index.php/ai/stable_diffusion/lora_making/

# %%
# @title ## 1.1. Install Dependencies
# @markdown Clone Kohya Trainer from GitHub and check for updates. Use textbox below if you want to checkout other branch or old commit. Leave it empty to stay the HEAD on main.  This will also install the required libraries.
import os
import zipfile
import shutil
import time
from subprocess import getoutput
from IPython.utils import capture
from google.colab import drive

# %store -r

# root_dir
root_dir = "/content"
deps_dir = os.path.join(root_dir, "deps")
repo_dir = os.path.join(root_dir, "kohya-trainer")
training_dir = os.path.join(root_dir, "LoRA")
pretrained_model = os.path.join(root_dir, "pretrained_model")
vae_dir = os.path.join(root_dir, "vae")
config_dir = os.path.join(training_dir, "config")

# repo_dir
accelerate_config = os.path.join(repo_dir, "accelerate_config/config.yaml")
tools_dir = os.path.join(repo_dir, "tools")
finetune_dir = os.path.join(repo_dir, "finetune")

for store in [
    "root_dir",
    "deps_dir",
    "repo_dir",
    "training_dir",
    "pretrained_model",
    "vae_dir",
    "accelerate_config",
    "tools_dir",
    "finetune_dir",
    "config_dir",
]:
    with capture.capture_output() as cap:
        # %store {store}
        del cap

repo_url = "https://github.com/Linaqruf/kohya-trainer"
bitsandytes_main_py = "/usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py"
branch = ""  # @param {type: "string"}
install_xformers = True  # @param {'type':'boolean'}
mount_drive = True  # @param {type: "boolean"}
verbose = False # @param {type: "boolean"}

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents


def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)


def clone_repo(url):
    if not os.path.exists(repo_dir):
        os.chdir(root_dir)
        # !git clone {url} {repo_dir}
    else:
        os.chdir(repo_dir)
        # !git pull origin {branch} if branch else !git pull


def ubuntu_deps(url, name, dst):
    # !wget {'-q' if not verbose else ''} --show-progress {url}
    with zipfile.ZipFile(name, "r") as deps:
        deps.extractall(dst)
    # !dpkg -i {dst}/*
    os.remove(name)
    shutil.rmtree(dst)


def install_dependencies():
    s = getoutput('nvidia-smi')

    if 'T4' in s:
        # !sed -i "s@cpu@cuda@" library/model_util.py

    # !pip install {'-q' if not verbose else ''} --upgrade -r requirements.txt
    # !pip install {'-q' if not verbose else ''} torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U

    if install_xformers:
        # !pip install {'-q' if not verbose else ''} xformers==0.0.19 triton==2.0.0 -U

    from accelerate.utils import write_basic_config

    if not os.path.exists(accelerate_config):
        write_basic_config(save_location=accelerate_config)


def remove_bitsandbytes_message(filename):
    welcome_message = """
def evaluate_cuda_setup():
    print('')
    print('='*35 + 'BUG REPORT' + '='*35)
    print('Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues')
    print('For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link')
    print('='*80)"""

    new_welcome_message = """
def evaluate_cuda_setup():
    import os
    if 'BITSANDBYTES_NOWELCOME' not in os.environ or str(os.environ['BITSANDBYTES_NOWELCOME']) == '0':
        print('')
        print('=' * 35 + 'BUG REPORT' + '=' * 35)
        print('Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues')
        print('For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link')
        print('To hide this message, set the BITSANDBYTES_NOWELCOME variable like so: export BITSANDBYTES_NOWELCOME=1')
        print('=' * 80)"""

    contents = read_file(filename)
    new_contents = contents.replace(welcome_message, new_welcome_message)
    write_file(filename, new_contents)


def main():
    os.chdir(root_dir)

    if mount_drive:
        if not os.path.exists("/content/drive"):
            drive.mount("/content/drive")

    for dir in [
        deps_dir,
        training_dir,
        config_dir,
        pretrained_model,
        vae_dir
    ]:
        os.makedirs(dir, exist_ok=True)

    clone_repo(repo_url)

    if branch:
        os.chdir(repo_dir)
        status = os.system(f"git checkout {branch}")
        if status != 0:
            raise Exception("Failed to checkout branch or commit")

    os.chdir(repo_dir)

    # !apt -y update {'-qq' if not verbose else ''}
    # !apt install libunwind8-dev {'-qq' if not verbose else ''}

    ubuntu_deps(
        "https://huggingface.co/Linaqruf/fast-repo/resolve/main/deb-libs.zip",
        "deb-libs.zip",
        deps_dir,
    )

    install_dependencies()
    time.sleep(3)

    remove_bitsandbytes_message(bitsandytes_main_py)

    os.environ["LD_PRELOAD"] = "libtcmalloc.so"
    os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
    os.environ["BITSANDBYTES_NOWELCOME"] = "1"
    os.environ["SAFETENSORS_FAST_GPU"] = "1"

    cuda_path = "/usr/local/cuda-11.8/targets/x86_64-linux/lib/"
    ld_library_path = os.environ.get("LD_LIBRARY_PATH", "")
    os.environ["LD_LIBRARY_PATH"] = f"{ld_library_path}:{cuda_path}"

main()
# Out:
# fatal: couldn't find remote ref if
# 31 packages can be upgraded. Run 'apt list --upgradable' to see them.
# libunwind-dev is already the newest version (1.2.1-9ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# deb-libs.zip        100%[===================>]   2.23M  --.-KB/s    in 0.01s
# (Reading database ... 123304 files and directories currently installed.)
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# Unpacking aria2 (1.35.0-1build1) over (1.35.0-1build1) ...
# Preparing to unpack .../google-perftools_2.5-2.2ubuntu3_all.deb ...
# Unpacking google-perftools (2.5-2.2ubuntu3) over (2.5-2.2ubuntu3) ...
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.35.0-1build1) over (1.35.0-1build1) ...
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.1_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.1) over (1.15.0-1ubuntu0.1) ...
# Preparing to unpack .../libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools4 (2.5-2.2ubuntu3) over (2.5-2.2ubuntu3) ...
# Preparing to unpack .../libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools-dev (2.5-2.2ubuntu3) over (2.5-2.2ubuntu3) ...
# Preparing to unpack .../liblz4-tool_1.9.2-2ubuntu0.20.04.1_all.deb ...
# Unpacking liblz4-tool (1.9.2-2ubuntu0.20.04.1) over (1.9.2-2ubuntu0.20.04.1) ...
# Preparing to unpack .../libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4 (2.5-2.2ubuntu3) over (2.5-2.2ubuntu3) ...
# Preparing to unpack .../lz4_1.9.2-2ubuntu0.20.04.1_amd64.deb ...
# Unpacking lz4 (1.9.2-2ubuntu0.20.04.1) over (1.9.2-2ubuntu0.20.04.1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# Setting up libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up lz4 (1.9.2-2ubuntu0.20.04.1) ...
# Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# Setting up libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# Setting up liblz4-tool (1.9.2-2ubuntu0.20.04.1) ...
# Setting up aria2 (1.35.0-1build1) ...
# Setting up google-perftools (2.5-2.2ubuntu3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#   Preparing metadata (setup.py) ... done
#   Building wheel for library (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 589.2 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 76.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 88.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 97.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 MB 8.6 MB/s eta 0:00:00

# %% [markdown]
# # II. Pretrained Model Selection

# %%
# @title ## 2.1. Download Available Model
import os

# %store -r

os.chdir(root_dir)

models = {
    "Animefull-final-pruned": "https://huggingface.co/Linaqruf/personal-backup/resolve/main/models/animefull-final-pruned.ckpt",
    "Anything-v3-1": "https://huggingface.co/cag/anything-v3-1/resolve/main/anything-v3-1.safetensors",
    "AnyLoRA": "https://huggingface.co/Linaqruf/stolen/resolve/main/pruned-models/AnyLoRA_noVae_fp16-pruned.safetensors",
    "AnyLoRA-anime-mix": "https://huggingface.co/Lykon/AnyLoRA/resolve/main/AAM_Anylora_AnimeMix.safetensors",
    "AnimePastelDream": "https://huggingface.co/Lykon/AnimePastelDream/resolve/main/AnimePastelDream_Soft_noVae_fp16.safetensors",
    "Chillout-mix": "https://huggingface.co/Linaqruf/stolen/resolve/main/pruned-models/chillout_mix-pruned.safetensors",
    "OpenJourney-v4": "https://huggingface.co/prompthero/openjourney-v4/resolve/main/openjourney-v4.ckpt",
    "Stable-Diffusion-v1-5": "https://huggingface.co/Linaqruf/stolen/resolve/main/pruned-models/stable_diffusion_1_5-pruned.safetensors",
}

v2_models = {
    "stable-diffusion-2-1-base": "https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.safetensors",
    "stable-diffusion-2-1-768v": "https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors",
    "plat-diffusion-v1-3-1": "https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1.safetensors",
    "replicant-v1": "https://huggingface.co/gsdf/Replicant-V1.0/resolve/main/Replicant-V1.0.safetensors",
    "illuminati-diffusion-v1-0": "https://huggingface.co/IlluminatiAI/Illuminati_Diffusion_v1.0/resolve/main/illuminati_diffusion_v1.0.safetensors",
    "illuminati-diffusion-v1-1": "https://huggingface.co/4eJIoBek/Illuminati-Diffusion-v1-1/resolve/main/illuminatiDiffusionV1_v11.safetensors",
    "waifu-diffusion-1-4-anime-e2": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e2.ckpt",
    "waifu-diffusion-1-5-e2": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-fp32.safetensors",
    "waifu-diffusion-1-5-e2-aesthetic": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp32.safetensors",
}

installModels = []
installv2Models = []

# @markdown ### SD1.x model
model_name = "Chillout-mix"  # @param ["", "Animefull-final-pruned", "Anything-v3-1", "AnyLoRA", "AnyLoRA-anime-mix", "AnimePastelDream", "Chillout-mix", "OpenJourney-v4", "Stable-Diffusion-v1-5"]
# @markdown ### SD2.x model
v2_model_name = "stable-diffusion-2-1-768v"  # @param ["", "stable-diffusion-2-1-base", "stable-diffusion-2-1-768v", "plat-diffusion-v1-3-1", "replicant-v1", "illuminati-diffusion-v1-0", "illuminati-diffusion-v1-1", "waifu-diffusion-1-4-anime-e2", "waifu-diffusion-1-5-e2", "waifu-diffusion-1-5-e2-aesthetic"]

if model_name:
    model_url = models.get(model_name)
    if model_url:
        installModels.append((model_name, model_url))

if v2_model_name:
    v2_model_url = v2_models.get(v2_model_name)
    if v2_model_url:
        installv2Models.append((v2_model_name, v2_model_url))


def install(checkpoint_name, url):
    ext = "ckpt" if url.endswith(".ckpt") else "safetensors"

    hf_token = "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"
    user_header = f'"Authorization: Bearer {hf_token}"'
    # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {pretrained_model} -o {checkpoint_name}.{ext} "{url}"


def install_checkpoint():
    for model in installModels:
        install(model[0], model[1])
    for v2model in installv2Models:
        install(v2model[0], v2model[1])


install_checkpoint()
# Out:
#  *** Download Progress Summary as of Thu Jul  6 08:46:23 2023 ***
# =
# [#e25cc0 2.3GiB/3.9GiB(59%) CN:16 DL:217MiB ETA:7s]
# FILE: /content/pretrained_model/Chillout-mix.safetensors
# -
#
#  *** Download Progress Summary as of Thu Jul  6 08:46:33 2023 ***
# =
# [#e25cc0 3.2GiB/3.9GiB(82%) CN:16 DL:88MiB ETA:8s]
# FILE: /content/pretrained_model/Chillout-mix.safetensors
# -
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e25cc0|OK  |   137MiB/s|/content/pretrained_model/Chillout-mix.safetensors
#
# Status Legend:
# (OK):download completed.
#  *** Download Progress Summary as of Thu Jul  6 08:46:54 2023 ***
# =
# [#d415da 1.7GiB/4.8GiB(35%) CN:16 DL:133MiB ETA:24s]
# FILE: /content/pretrained_model/stable-diffusion-2-1-768v.safetensors
# -
#
#  *** Download Progress Summary as of Thu Jul  6 08:47:04 2023 ***
# =
# [#d415da 3.7GiB/4.8GiB(77%) CN:16 DL:183MiB ETA:6s]
# FILE: /content/pretrained_model/stable-diffusion-2-1-768v.safetensors
# -
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d415da|OK  |   160MiB/s|/content/pretrained_model/stable-diffusion-2-1-768v.safetensors
#
# Status Legend:
# (OK):download completed.

# %%
# @title ## 2.2. Download Custom Model
import os

# %store -r

os.chdir(root_dir)

# @markdown ### Custom model
modelUrls = ""  # @param {'type': 'string'}

def install(url):
    base_name = os.path.basename(url)

    if "drive.google.com" in url:
        os.chdir(pretrained_model)
        # !gdown --fuzzy {url}
    elif "huggingface.co" in url:
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        # @markdown Change this part with your own huggingface token if you need to download your private model
        hf_token = "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"  # @param {type:"string"}
        user_header = f'"Authorization: Bearer {hf_token}"'
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {pretrained_model} -o {base_name} {url}
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {pretrained_model} {url}

if modelUrls:
    urls = modelUrls.split(",")
    for url in urls:
        install(url.strip())

# %%
# @title ## 2.3. Download Available VAE (Optional)
import os

# %store -r

os.chdir(root_dir)

vaes = {
    "none": "",
    "anime.vae.pt": "https://huggingface.co/Linaqruf/personal-backup/resolve/main/vae/animevae.pt",
    "waifudiffusion.vae.pt": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt",
    "stablediffusion.vae.pt": "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt",
}
install_vaes = []

# @markdown Select one of the VAEs to download, select `none` for not download VAE:
vae_name = "stablediffusion.vae.pt"  # @param ["none", "anime.vae.pt", "waifudiffusion.vae.pt", "stablediffusion.vae.pt"]

if vae_name in vaes:
    vae_url = vaes[vae_name]
    if vae_url:
        install_vaes.append((vae_name, vae_url))


def install(vae_name, url):
    hf_token = "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"
    user_header = f'"Authorization: Bearer {hf_token}"'
    # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {vae_dir} -o {vae_name} "{url}"


def install_vae():
    for vae in install_vaes:
        install(vae[0], vae[1])


install_vae()
# Out:
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 151503|OK  |   221MiB/s|/content/vae/stablediffusion.vae.pt
#
# Status Legend:
# (OK):download completed.

# %% [markdown]
# # III. Data Acquisition
#
# You have three options for acquiring your dataset:
#
# 1. Uploading it to Colab's local files.
# 2. Bulk downloading images from Danbooru using the `Simple Booru Scraper`.
# 3. Locating your dataset from Google Drive.

# %%
# @title ## 3.1. Locating Train Data Directory
# @markdown Define the location of your training data. This cell will also create a folder based on your input. Regularization Images is optional and can be skipped.
import os
from IPython.utils import capture

# %store -r

train_data_dir = "/content/LoRA/train_data"  # @param {type:'string'}
reg_data_dir = "/content/LoRA/reg_data"  # @param {type:'string'}

for dir in [train_data_dir, reg_data_dir]:
    if dir:
        with capture.capture_output() as cap:
            os.makedirs(dir, exist_ok=True)
            # %store dir
            del cap

print(f"Your train data directory : {train_data_dir}")
if reg_data_dir:
    print(f"Your reg data directory : {reg_data_dir}")
# Out:
# Your train data directory : /content/LoRA/train_data
# Your reg data directory : /content/LoRA/reg_data

# %%
# @title ## 3.2. Unzip Dataset

import os
import shutil
from pathlib import Path

#@title ## Unzip Dataset
# @markdown Use this section if your dataset is in a `zip` file and has been uploaded somewhere. This code cell will download your dataset and automatically extract it to the `train_data_dir` if the `unzip_to` variable is empty.
zipfile_url = "/content/drive/MyDrive/Lora_rum_sama/rum-train-images.zip" #@param {type:"string"}
zipfile_name = "zipfile.zip"
unzip_to = "" #@param {type:"string"}

hf_token = "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"
user_header = f'"Authorization: Bearer {hf_token}"'

if unzip_to:
    os.makedirs(unzip_to, exist_ok=True)
else:
    unzip_to = train_data_dir


def download_dataset(url):
    if url.startswith("/content"):
        return url
    elif "drive.google.com" in url:
        os.chdir(root_dir)
        # !gdown --fuzzy {url}
        return f"{root_dir}/{zipfile_name}"
    elif "huggingface.co" in url:
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {root_dir} -o {zipfile_name} {url}
        return f"{root_dir}/{zipfile_name}"
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {root_dir} -o {zipfile_name} {url}
        return f"{root_dir}/{zipfile_name}"


def extract_dataset(zip_file, output_path):
    if zip_file.startswith("/content"):
        # !unzip -j -o {zip_file} -d "{output_path}"
    else:
        # !unzip -j -o "{zip_file}" -d "{output_path}"


def remove_files(train_dir, files_to_move):
    for filename in os.listdir(train_dir):
        file_path = os.path.join(train_dir, filename)
        if filename in files_to_move:
            if not os.path.exists(file_path):
                shutil.move(file_path, training_dir)
            else:
                os.remove(file_path)


zip_file = download_dataset(zipfile_url)
extract_dataset(zip_file, unzip_to)
os.remove(zip_file)

files_to_move = (
    "meta_cap.json",
    "meta_cap_dd.json",
    "meta_lat.json",
    "meta_clean.json",
)

remove_files(train_data_dir, files_to_move)
# Out:
# Archive:  /content/drive/MyDrive/Lora_rum_sama/rum-train-images.zip
#   inflating: /content/LoRA/train_data/rum-1.jpg
#   inflating: /content/LoRA/train_data/._rum-1.jpg
#   inflating: /content/LoRA/train_data/rum-2.jpg
#   inflating: /content/LoRA/train_data/._rum-2.jpg
#   inflating: /content/LoRA/train_data/rum-3.jpg
#   inflating: /content/LoRA/train_data/._rum-3.jpg
#   inflating: /content/LoRA/train_data/rum-5.jpg
#   inflating: /content/LoRA/train_data/._rum-5.jpg
#   inflating: /content/LoRA/train_data/rum-6.jpg
#   inflating: /content/LoRA/train_data/._rum-6.jpg
#   inflating: /content/LoRA/train_data/rum-8.jpg
#   inflating: /content/LoRA/train_data/._rum-8.jpg
#   inflating: /content/LoRA/train_data/rum-9.jpeg
#   inflating: /content/LoRA/train_data/._rum-9.jpeg
#   inflating: /content/LoRA/train_data/rum-10.jpeg
#   inflating: /content/LoRA/train_data/._rum-10.jpeg
#   inflating: /content/LoRA/train_data/rum-13.JPG
#   inflating: /content/LoRA/train_data/._rum-13.JPG
#   inflating: /content/LoRA/train_data/rum-14.jpeg
#   inflating: /content/LoRA/train_data/._rum-14.jpeg
#   inflating: /content/LoRA/train_data/rum-15.JPG
#   inflating: /content/LoRA/train_data/._rum-15.JPG
#   inflating: /content/LoRA/train_data/rum-16.JPG
#   inflating: /content/LoRA/train_data/._rum-16.JPG
#   inflating: /content/LoRA/train_data/rum-17.jpeg
#   inflating: /content/LoRA/train_data/._rum-17.jpeg
#   inflating: /content/LoRA/train_data/rum-18.JPG
#   inflating: /content/LoRA/train_data/._rum-18.JPG
#   inflating: /content/LoRA/train_data/rum-21.JPG
#   inflating: /content/LoRA/train_data/._rum-21.JPG
#   inflating: /content/LoRA/train_data/rum-22.JPG
#   inflating: /content/LoRA/train_data/._rum-22.JPG
#   inflating: /content/LoRA/train_data/rum-26.JPG
#   inflating: /content/LoRA/train_data/._rum-26.JPG
#   inflating: /content/LoRA/train_data/rum-27.JPG
#   inflating: /content/LoRA/train_data/._rum-27.JPG
#   inflating: /content/LoRA/train_data/rum-28.JPG
#   inflating: /content/LoRA/train_data/._rum-28.JPG
#   inflating: /content/LoRA/train_data/rum-30.JPG
#   inflating: /content/LoRA/train_data/._rum-30.JPG
#   inflating: /content/LoRA/train_data/rum-31.JPG
#   inflating: /content/LoRA/train_data/._rum-31.JPG
#   inflating: /content/LoRA/train_data/rum-32.JPG
#   inflating: /content/LoRA/train_data/._rum-32.JPG
#   inflating: /content/LoRA/train_data/rum-33.JPG
#   inflating: /content/LoRA/train_data/._rum-33.JPG
#   inflating: /content/LoRA/train_data/rum-34.JPG
#   inflating: /content/LoRA/train_data/._rum-34.JPG
#   inflating: /content/LoRA/train_data/rum-35.JPG
#   inflating: /content/LoRA/train_data/._rum-35.JPG
#   inflating: /content/LoRA/train_data/rum-36.JPG
#   inflating: /content/LoRA/train_data/._rum-36.JPG
#   inflating: /content/LoRA/train_data/rum-37.JPG
#   inflating: /content/LoRA/train_data/._rum-37.JPG
#   inflating: /content/LoRA/train_data/rum-38.JPG
#   inflating: /content/LoRA/train_data/._rum-38.JPG
#   inflating: /content/LoRA/train_data/rum-39.JPG
#   inflating: /content/LoRA/train_data/._rum-39.JPG
#   inflating: /content/LoRA/train_data/rum-42.JPG
#   inflating: /content/LoRA/train_data/._rum-42.JPG
#   inflating: /content/LoRA/train_data/rum-43.JPG
#   inflating: /content/LoRA/train_data/._rum-43.JPG
#   inflating: /content/LoRA/train_data/rum-44.JPG
#   inflating: /content/LoRA/train_data/._rum-44.JPG
#   inflating: /content/LoRA/train_data/rum-46.JPG
#   inflating: /content/LoRA/train_data/._rum-46.JPG
#   inflating: /content/LoRA/train_data/rum-48.JPG
#   inflating: /content/LoRA/train_data/._rum-48.JPG
#   inflating: /content/LoRA/train_data/rum-49.JPG
#   inflating: /content/LoRA/train_data/._rum-49.JPG
#   inflating: /content/LoRA/train_data/rum-50.JPG
#   inflating: /content/LoRA/train_data/._rum-50.JPG
#   inflating: /content/LoRA/train_data/rum-51.JPG
#   inflating: /content/LoRA/train_data/._rum-51.JPG
#   inflating: /content/LoRA/train_data/rum-52.JPG
#   inflating: /content/LoRA/train_data/._rum-52.JPG
#   inflating: /content/LoRA/train_data/rum-53.JPG
#   inflating: /content/LoRA/train_data/._rum-53.JPG
#   inflating: /content/LoRA/train_data/rum-56.JPG
#   inflating: /content/LoRA/train_data/._rum-56.JPG
#   inflating: /content/LoRA/train_data/rum-57.JPG
#   inflating: /content/LoRA/train_data/._rum-57.JPG
#   inflating: /content/LoRA/train_data/rum-60.JPG
#   inflating: /content/LoRA/train_data/._rum-60.JPG
#   inflating: /content/LoRA/train_data/rum-61.JPG
#   inflating: /content/LoRA/train_data/._rum-61.JPG
#   inflating: /content/LoRA/train_data/rum-65.JPG
#   inflating: /content/LoRA/train_data/._rum-65.JPG
#   inflating: /content/LoRA/train_data/rum-67.JPG
#   inflating: /content/LoRA/train_data/._rum-67.JPG
#   inflating: /content/LoRA/train_data/rum-68.JPG
#   inflating: /content/LoRA/train_data/._rum-68.JPG
#   inflating: /content/LoRA/train_data/rum-71.JPG
#   inflating: /content/LoRA/train_data/._rum-71.JPG
#   inflating: /content/LoRA/train_data/rum-72.JPG
#   inflating: /content/LoRA/train_data/._rum-72.JPG
#   inflating: /content/LoRA/train_data/rum-75.JPG
#   inflating: /content/LoRA/train_data/._rum-75.JPG
#   inflating: /content/LoRA/train_data/rum-80.JPG
#   inflating: /content/LoRA/train_data/._rum-80.JPG
#   inflating: /content/LoRA/train_data/rum-81.JPG
#   inflating: /content/LoRA/train_data/._rum-81.JPG
#   inflating: /content/LoRA/train_data/rum-82.JPG
#   inflating: /content/LoRA/train_data/._rum-82.JPG
#   inflating: /content/LoRA/train_data/rum-83.JPG
#   inflating: /content/LoRA/train_data/._rum-83.JPG
#   inflating: /content/LoRA/train_data/rum-85.JPG
#   inflating: /content/LoRA/train_data/._rum-85.JPG
#   inflating: /content/LoRA/train_data/rum-86.jpg
#   inflating: /content/LoRA/train_data/._rum-86.jpg
#   inflating: /content/LoRA/train_data/rum-88.jpg
#   inflating: /content/LoRA/train_data/._rum-88.jpg
#   inflating: /content/LoRA/train_data/rum-89.jpg
#   inflating: /content/LoRA/train_data/._rum-89.jpg
#   inflating: /content/LoRA/train_data/rum-90.jpg
#   inflating: /content/LoRA/train_data/._rum-90.jpg
#   inflating: /content/LoRA/train_data/rum-91.jpg
#   inflating: /content/LoRA/train_data/._rum-91.jpg
#   inflating: /content/LoRA/train_data/rum-92.jpg
#   inflating: /content/LoRA/train_data/._rum-92.jpg
#   inflating: /content/LoRA/train_data/rum-93.jpg
#   inflating: /content/LoRA/train_data/._rum-93.jpg
#   inflating: /content/LoRA/train_data/rum-94.jpg
#   inflating: /content/LoRA/train_data/._rum-94.jpg
#   inflating: /content/LoRA/train_data/rum-95.jpg
#   inflating: /content/LoRA/train_data/._rum-95.jpg
#   inflating: /content/LoRA/train_data/rum-96.jpg
#   inflating: /content/LoRA/train_data/._rum-96.jpg
#   inflating: /content/LoRA/train_data/rum-97.jpg
#   inflating: /content/LoRA/train_data/._rum-97.jpg
#   inflating: /content/LoRA/train_data/rum-98.jpg
#   inflating: /content/LoRA/train_data/._rum-98.jpg
#   inflating: /content/LoRA/train_data/rum-99.jpg
#   inflating: /content/LoRA/train_data/._rum-99.jpg
#   inflating: /content/LoRA/train_data/rum-100.jpg
#   inflating: /content/LoRA/train_data/._rum-100.jpg
#   inflating: /content/LoRA/train_data/rum-101.png
#   inflating: /content/LoRA/train_data/._rum-101.png
#   inflating: /content/LoRA/train_data/rum-102.png
#   inflating: /content/LoRA/train_data/._rum-102.png
#   inflating: /content/LoRA/train_data/rum-105.png
#   inflating: /content/LoRA/train_data/._rum-105.png
#   inflating: /content/LoRA/train_data/rum-106.png
#   inflating: /content/LoRA/train_data/._rum-106.png
#   inflating: /content/LoRA/train_data/rum-107.png
#   inflating: /content/LoRA/train_data/._rum-107.png
#   inflating: /content/LoRA/train_data/rum-108.png
#   inflating: /content/LoRA/train_data/._rum-108.png
#   inflating: /content/LoRA/train_data/rum-109.png
#   inflating: /content/LoRA/train_data/._rum-109.png
#   inflating: /content/LoRA/train_data/rum-110.png
#   inflating: /content/LoRA/train_data/._rum-110.png
#   inflating: /content/LoRA/train_data/rum-111.png
#   inflating: /content/LoRA/train_data/._rum-111.png
#   inflating: /content/LoRA/train_data/rum-112.png
#   inflating: /content/LoRA/train_data/._rum-112.png
#   inflating: /content/LoRA/train_data/rum-113.png
#   inflating: /content/LoRA/train_data/._rum-113.png
#   inflating: /content/LoRA/train_data/rum-114.png
#   inflating: /content/LoRA/train_data/._rum-114.png
#   inflating: /content/LoRA/train_data/rum-115.png
#   inflating: /content/LoRA/train_data/._rum-115.png
#   inflating: /content/LoRA/train_data/rum-116.png
#   inflating: /content/LoRA/train_data/._rum-116.png
#   inflating: /content/LoRA/train_data/rum-117.png
#   inflating: /content/LoRA/train_data/._rum-117.png
#   inflating: /content/LoRA/train_data/rum-118.png
#   inflating: /content/LoRA/train_data/._rum-118.png
#   inflating: /content/LoRA/train_data/rum-119.png
#   inflating: /content/LoRA/train_data/._rum-119.png
#   inflating: /content/LoRA/train_data/rum-120.png
#   inflating: /content/LoRA/train_data/._rum-120.png
#   inflating: /content/LoRA/train_data/rum-121.png
#   inflating: /content/LoRA/train_data/._rum-121.png
#   inflating: /content/LoRA/train_data/rum-122.png
#   inflating: /content/LoRA/train_data/._rum-122.png

# %% [markdown]
# # IV. Data Preprocessing

# %%
# @title ## 4.1. Data Cleaning
import os
import random
import concurrent.futures
from tqdm import tqdm
from PIL import Image

# %store -r

os.chdir(root_dir)

test = os.listdir(train_data_dir)
# @markdown This section will delete unnecessary files and unsupported media such as `.mp4`, `.webm`, and `.gif`.
# @markdown Set the `convert` parameter to convert your transparent dataset with an alpha channel (RGBA) to RGB and give it a white background.
convert = False  # @param {type:"boolean"}
# @markdown You can choose to give it a `random_color` background instead of white by checking the corresponding option.
random_color = False  # @param {type:"boolean"}
# @markdown Use the `recursive` option to preprocess subfolders as well.
recursive = False #  @param {type:"boolean"}


batch_size = 32
supported_types = [
    ".png",
    ".jpg",
    ".jpeg",
    ".webp",
    ".bmp",
    ".caption",
    ".npz",
    ".txt",
    ".json",
]

background_colors = [
    (255, 255, 255),
    (0, 0, 0),
    (255, 0, 0),
    (0, 255, 0),
    (0, 0, 255),
    (255, 255, 0),
    (255, 0, 255),
    (0, 255, 255),
]

def clean_directory(directory):
    for item in os.listdir(directory):
        file_path = os.path.join(directory, item)
        if os.path.isfile(file_path):
            file_ext = os.path.splitext(item)[1]
            if file_ext not in supported_types:
                print(f"Deleting file {item} from {directory}")
                os.remove(file_path)
        elif os.path.isdir(file_path) and recursive:
            clean_directory(file_path)

def process_image(image_path):
    img = Image.open(image_path)
    img_dir, image_name = os.path.split(image_path)

    if img.mode in ("RGBA", "LA"):
        if random_color:
            background_color = random.choice(background_colors)
        else:
            background_color = (255, 255, 255)
        bg = Image.new("RGB", img.size, background_color)
        bg.paste(img, mask=img.split()[-1])

        if image_name.endswith(".webp"):
            bg = bg.convert("RGB")
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            bg.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            bg.save(image_path, "PNG")
            print(f" Converted image: {image_name}")
    else:
        if image_name.endswith(".webp"):
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            img.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            img.save(image_path, "PNG")

def find_images(directory):
    images = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".png") or file.endswith(".webp"):
                images.append(os.path.join(root, file))
    return images

clean_directory(train_data_dir)
images = find_images(train_data_dir)
num_batches = len(images) // batch_size + 1

if convert:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        for i in tqdm(range(num_batches)):
            start = i * batch_size
            end = start + batch_size
            batch = images[start:end]
            executor.map(process_image, batch)

    print("All images have been converted")
# Out:
# Deleting file ._rum-31.JPG from /content/LoRA/train_data
# Deleting file rum-28.JPG from /content/LoRA/train_data
# Deleting file rum-67.JPG from /content/LoRA/train_data
# Deleting file ._rum-28.JPG from /content/LoRA/train_data
# Deleting file ._rum-35.JPG from /content/LoRA/train_data
# Deleting file ._rum-53.JPG from /content/LoRA/train_data
# Deleting file rum-46.JPG from /content/LoRA/train_data
# Deleting file rum-33.JPG from /content/LoRA/train_data
# Deleting file ._rum-50.JPG from /content/LoRA/train_data
# Deleting file rum-37.JPG from /content/LoRA/train_data
# Deleting file ._rum-57.JPG from /content/LoRA/train_data
# Deleting file rum-32.JPG from /content/LoRA/train_data
# Deleting file rum-72.JPG from /content/LoRA/train_data
# Deleting file ._rum-27.JPG from /content/LoRA/train_data
# Deleting file rum-81.JPG from /content/LoRA/train_data
# Deleting file ._rum-16.JPG from /content/LoRA/train_data
# Deleting file rum-30.JPG from /content/LoRA/train_data
# Deleting file rum-31.JPG from /content/LoRA/train_data
# Deleting file ._rum-82.JPG from /content/LoRA/train_data
# Deleting file rum-38.JPG from /content/LoRA/train_data
# Deleting file ._rum-85.JPG from /content/LoRA/train_data
# Deleting file rum-56.JPG from /content/LoRA/train_data
# Deleting file ._rum-49.JPG from /content/LoRA/train_data
# Deleting file ._rum-44.JPG from /content/LoRA/train_data
# Deleting file rum-51.JPG from /content/LoRA/train_data
# Deleting file rum-34.JPG from /content/LoRA/train_data
# Deleting file rum-52.JPG from /content/LoRA/train_data
# Deleting file ._rum-68.JPG from /content/LoRA/train_data
# Deleting file ._rum-26.JPG from /content/LoRA/train_data
# Deleting file rum-39.JPG from /content/LoRA/train_data
# Deleting file rum-65.JPG from /content/LoRA/train_data
# Deleting file rum-50.JPG from /content/LoRA/train_data
# Deleting file ._rum-60.JPG from /content/LoRA/train_data
# Deleting file ._rum-52.JPG from /content/LoRA/train_data
# Deleting file ._rum-51.JPG from /content/LoRA/train_data
# Deleting file ._rum-46.JPG from /content/LoRA/train_data
# Deleting file ._rum-61.JPG from /content/LoRA/train_data
# Deleting file rum-35.JPG from /content/LoRA/train_data
# Deleting file ._rum-34.JPG from /content/LoRA/train_data
# Deleting file ._rum-30.JPG from /content/LoRA/train_data
# Deleting file ._rum-15.JPG from /content/LoRA/train_data
# Deleting file rum-53.JPG from /content/LoRA/train_data
# Deleting file ._rum-48.JPG from /content/LoRA/train_data
# Deleting file rum-16.JPG from /content/LoRA/train_data
# Deleting file ._rum-80.JPG from /content/LoRA/train_data
# Deleting file rum-57.JPG from /content/LoRA/train_data
# Deleting file ._rum-83.JPG from /content/LoRA/train_data
# Deleting file ._rum-18.JPG from /content/LoRA/train_data
# Deleting file rum-85.JPG from /content/LoRA/train_data
# Deleting file rum-80.JPG from /content/LoRA/train_data
# Deleting file rum-60.JPG from /content/LoRA/train_data
# Deleting file rum-68.JPG from /content/LoRA/train_data
# Deleting file rum-75.JPG from /content/LoRA/train_data
# Deleting file rum-82.JPG from /content/LoRA/train_data
# Deleting file ._rum-39.JPG from /content/LoRA/train_data
# Deleting file ._rum-43.JPG from /content/LoRA/train_data
# Deleting file rum-22.JPG from /content/LoRA/train_data
# Deleting file rum-26.JPG from /content/LoRA/train_data
# Deleting file ._rum-21.JPG from /content/LoRA/train_data
# Deleting file ._rum-65.JPG from /content/LoRA/train_data
# Deleting file rum-71.JPG from /content/LoRA/train_data
# Deleting file ._rum-71.JPG from /content/LoRA/train_data
# Deleting file rum-44.JPG from /content/LoRA/train_data
# Deleting file rum-49.JPG from /content/LoRA/train_data
# Deleting file ._rum-36.JPG from /content/LoRA/train_data
# Deleting file ._rum-67.JPG from /content/LoRA/train_data
# Deleting file ._rum-42.JPG from /content/LoRA/train_data
# Deleting file rum-61.JPG from /content/LoRA/train_data
# Deleting file ._rum-22.JPG from /content/LoRA/train_data
# Deleting file ._rum-32.JPG from /content/LoRA/train_data
# Deleting file ._rum-56.JPG from /content/LoRA/train_data
# Deleting file ._rum-81.JPG from /content/LoRA/train_data
# Deleting file rum-15.JPG from /content/LoRA/train_data
# Deleting file rum-83.JPG from /content/LoRA/train_data
# Deleting file rum-13.JPG from /content/LoRA/train_data
# Deleting file ._rum-13.JPG from /content/LoRA/train_data
# Deleting file ._rum-75.JPG from /content/LoRA/train_data
# Deleting file rum-48.JPG from /content/LoRA/train_data
# Deleting file rum-43.JPG from /content/LoRA/train_data
# Deleting file rum-42.JPG from /content/LoRA/train_data
# Deleting file ._rum-37.JPG from /content/LoRA/train_data
# Deleting file rum-18.JPG from /content/LoRA/train_data
# Deleting file rum-36.JPG from /content/LoRA/train_data
# Deleting file ._rum-33.JPG from /content/LoRA/train_data
# Deleting file rum-21.JPG from /content/LoRA/train_data
# Deleting file ._rum-38.JPG from /content/LoRA/train_data
# Deleting file rum-27.JPG from /content/LoRA/train_data
# Deleting file ._rum-72.JPG from /content/LoRA/train_data

# %% [markdown]
# ## 4.2. Data Annotation
# You can choose to train a model using captions. We're using [BLIP](https://huggingface.co/spaces/Salesforce/BLIP) for image captioning and [Waifu Diffusion 1.4 Tagger](https://huggingface.co/spaces/SmilingWolf/wd-v1-4-tags) for image tagging similar to Danbooru.
# - Use BLIP Captioning for: `General Images`
# - Use Waifu Diffusion 1.4 Tagger V2 for: `Anime and Manga-style Images`

# %%
#@title ### 4.2.1. BLIP Captioning
#@markdown BLIP is a pre-training framework for unified vision-language understanding and generation, which achieves state-of-the-art results on a wide range of vision-language tasks. It can be used as a tool for image captioning, for example, `astronaut riding a horse in space`.
import os

os.chdir(finetune_dir)

batch_size = 8 #@param {type:'number'}
max_data_loader_n_workers = 2 #@param {type:'number'}
beam_search = True #@param {type:'boolean'}
min_length = 5 #@param {type:"slider", min:0, max:100, step:5.0}
max_length = 75 #@param {type:"slider", min:0, max:100, step:5.0}
#@markdown Use the `recursive` option to process subfolders as well, useful for multi-concept training.
recursive = False #@param {type:"boolean"}
#@markdown Debug while captioning, it will print your image file with generated captions.
verbose_logging = True #@param {type:"boolean"}

config = {
    "_train_data_dir" : train_data_dir,
    "batch_size" : batch_size,
    "beam_search" : beam_search,
    "min_length" : min_length,
    "max_length" : max_length,
    "debug" : verbose_logging,
    "caption_extension" : ".caption",
    "max_data_loader_n_workers" : max_data_loader_n_workers,
    "recursive" : recursive
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python make_captions.py {args}"

os.chdir(finetune_dir)
# !{final_args}
# Out:
# load images from /content/LoRA/train_data
# found 88 images.
# loading BLIP caption: https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# Downloading (…)solve/main/vocab.txt: 100% 232k/232k [00:00<00:00, 34.7MB/s]
# Downloading (…)okenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 150kB/s]
# Downloading (…)lve/main/config.json: 100% 570/570 [00:00<00:00, 3.17MB/s]
# 100% 1.66G/1.66G [01:21<00:00, 21.9MB/s]
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# BLIP loaded
#   0% 0/11 [00:00<?, ?it/s]Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-1.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-1.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-10.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-10.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-108.png, error: cannot identify image file '/content/LoRA/train_data/._rum-108.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-109.png, error: cannot identify image file '/content/LoRA/train_data/._rum-109.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-100.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-100.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-101.png, error: cannot identify image file '/content/LoRA/train_data/._rum-101.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-110.png, error: cannot identify image file '/content/LoRA/train_data/._rum-110.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-102.png, error: cannot identify image file '/content/LoRA/train_data/._rum-102.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-111.png, error: cannot identify image file '/content/LoRA/train_data/._rum-111.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-112.png, error: cannot identify image file '/content/LoRA/train_data/._rum-112.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-105.png, error: cannot identify image file '/content/LoRA/train_data/._rum-105.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-106.png, error: cannot identify image file '/content/LoRA/train_data/._rum-106.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-113.png, error: cannot identify image file '/content/LoRA/train_data/._rum-113.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-114.png, error: cannot identify image file '/content/LoRA/train_data/._rum-114.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-107.png, error: cannot identify image file '/content/LoRA/train_data/._rum-107.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-115.png, error: cannot identify image file '/content/LoRA/train_data/._rum-115.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-17.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-17.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-116.png, error: cannot identify image file '/content/LoRA/train_data/._rum-116.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-117.png, error: cannot identify image file '/content/LoRA/train_data/._rum-117.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-2.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-2.jpg'
#   9% 1/11 [00:00<00:03,  3.18it/s]Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-118.png, error: cannot identify image file '/content/LoRA/train_data/._rum-118.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-3.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-3.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-119.png, error: cannot identify image file '/content/LoRA/train_data/._rum-119.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-5.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-5.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-120.png, error: cannot identify image file '/content/LoRA/train_data/._rum-120.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-6.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-6.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-121.png, error: cannot identify image file '/content/LoRA/train_data/._rum-121.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-122.png, error: cannot identify image file '/content/LoRA/train_data/._rum-122.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-8.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-8.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-14.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-14.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-86.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-86.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-89.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-89.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-9.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-9.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-90.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-90.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-88.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-88.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-91.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-91.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-92.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-92.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-96.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-96.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-93.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-93.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-97.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-97.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-94.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-94.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-95.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-95.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-98.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-98.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-99.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-99.jpg'
#  55% 6/11 [00:00<00:00,  6.89it/s]/content/LoRA/train_data/rum-1.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-10.jpeg a cat laying on a blue blanket on a bed
# /content/LoRA/train_data/rum-100.jpg a cat is sitting on a bed with a blanket
# /content/LoRA/train_data/rum-101.png a cat laying on a bed with a white sheet
# /content/LoRA/train_data/rum-102.png a cat laying on a bed with a white sheet
# /content/LoRA/train_data/rum-105.png a cat sitting on a bed with a white sheet
# /content/LoRA/train_data/rum-106.png a cat sitting on a bed with a remote control
# /content/LoRA/train_data/rum-107.png a cat sitting on a bed looking at the camera
# /content/LoRA/train_data/rum-108.png a cat sitting on a bed looking up
# /content/LoRA/train_data/rum-109.png a cat sitting on a bed with a white blanket
# /content/LoRA/train_data/rum-110.png a person holding a cat with their hands
# /content/LoRA/train_data/rum-111.png a person holding a cat with their paws
# /content/LoRA/train_data/rum-112.png a woman holding a cat in her lap
# /content/LoRA/train_data/rum-113.png a cat sitting on a mat in a room
# /content/LoRA/train_data/rum-114.png a cat sitting on a bed with a white sheet
# /content/LoRA/train_data/rum-115.png a cat sitting on a bed looking at the camera
# /content/LoRA/train_data/rum-116.png a cat sitting on a bed with a white blanket
# /content/LoRA/train_data/rum-117.png a cat laying on a bed with a white sheet
# /content/LoRA/train_data/rum-118.png a cat laying on a bed with a white sheet
# /content/LoRA/train_data/rum-119.png a cat laying on a bed with a white sheet
# /content/LoRA/train_data/rum-120.png a cat laying on a bed with a white sheet
# /content/LoRA/train_data/rum-121.png a cat is playing with a toy on the floor
# /content/LoRA/train_data/rum-122.png a cat laying on a mat on a floor
# /content/LoRA/train_data/rum-14.jpeg a cat sitting in a cat tree looking out
# /content/LoRA/train_data/rum-17.jpeg a cat laying on a table with a cardboard box
# /content/LoRA/train_data/rum-2.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-3.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-5.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-6.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-8.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-86.jpg a cat laying on a bed with a blanket
# /content/LoRA/train_data/rum-88.jpg a cat laying on a bed with a stuffed animal
# /content/LoRA/train_data/rum-89.jpg a cat sitting on a bed in a room
# /content/LoRA/train_data/rum-9.jpeg a cat laying on a mat with a toy
# /content/LoRA/train_data/rum-90.jpg a cat sitting on a bed with a cat tree
# /content/LoRA/train_data/rum-91.jpg a cat sitting on a bed with a blanket
# /content/LoRA/train_data/rum-92.jpg a cat sitting on a bed with a cat tree
# /content/LoRA/train_data/rum-93.jpg a cat is standing in front of a cat tree
# /content/LoRA/train_data/rum-94.jpg a cat is sitting on a blanket in a room
# /content/LoRA/train_data/rum-95.jpg a cat laying on a white blanket next to a stuffed animal
# 100% 11/11 [00:18<00:00,  1.72s/it]
# /content/LoRA/train_data/rum-96.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-97.jpg a cat laying on a bed with a white blanket
# /content/LoRA/train_data/rum-98.jpg a cat sitting on a bed with a white blanket
# /content/LoRA/train_data/rum-99.jpg a cat laying on a bed with a white blanket
# done!

# %%
#@title ### 4.2.2. Waifu Diffusion 1.4 Tagger V2
import os
# %store -r

os.chdir(finetune_dir)

#@markdown [Waifu Diffusion 1.4 Tagger V2](https://huggingface.co/spaces/SmilingWolf/wd-v1-4-tags) is a Danbooru-styled image classification model developed by SmilingWolf. It can also be useful for general image tagging, for example, `1girl, solo, looking_at_viewer, short_hair, bangs, simple_background`.
batch_size = 8 #@param {type:'number'}
max_data_loader_n_workers = 2 #@param {type:'number'}
model = "SmilingWolf/wd-v1-4-convnextv2-tagger-v2" #@param ["SmilingWolf/wd-v1-4-convnextv2-tagger-v2", "SmilingWolf/wd-v1-4-swinv2-tagger-v2", "SmilingWolf/wd-v1-4-convnext-tagger-v2", "SmilingWolf/wd-v1-4-vit-tagger-v2"]
#@markdown Use the `recursive` option to process subfolders as well, useful for multi-concept training.
recursive = False #@param {type:"boolean"}
#@markdown Debug while tagging, it will print your image file with general tags and character tags.
verbose_logging = True #@param {type:"boolean"}
#@markdown Separate `undesired_tags` with comma `(,)` if you want to remove multiple tags, e.g. `1girl,solo,smile`.
undesired_tags = "" #@param {type:'string'}
#@markdown  Adjust `general_threshold` for pruning tags (less tags, less flexible). `character_threshold` is useful if you want to train with character tags, e.g. `hakurei reimu`.
general_threshold = 0.35 #@param {type:"slider", min:0, max:1, step:0.05}
character_threshold = 0.35 #@param {type:"slider", min:0, max:1, step:0.05}

config = {
    "_train_data_dir": train_data_dir,
    "batch_size": batch_size,
    "repo_id": model,
    "recursive": recursive,
    "remove_underscore": True,
    "general_threshold": general_threshold,
    "character_threshold": character_threshold,
    "caption_extension": ".txt",
    "max_data_loader_n_workers": max_data_loader_n_workers,
    "debug": verbose_logging,
    "undesired_tags": undesired_tags
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python tag_images_by_wd14_tagger.py {args}"

os.chdir(finetune_dir)
# !{final_args}
# Out:
# downloading wd14 tagger model from hf_hub. id: SmilingWolf/wd-v1-4-convnextv2-tagger-v2
# Downloading keras_metadata.pb: 100% 477k/477k [00:00<00:00, 47.2MB/s]
# Downloading saved_model.pb: 100% 6.17M/6.17M [00:00<00:00, 84.6MB/s]
# Downloading (…)in/selected_tags.csv: 100% 254k/254k [00:00<00:00, 43.9MB/s]
# Downloading (…).data-00000-of-00001: 100% 388M/388M [00:01<00:00, 340MB/s]
# Downloading variables.index: 100% 25.5k/25.5k [00:00<00:00, 98.5MB/s]
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# found 88 images.
#   0% 0/11 [00:00<?, ?it/s]Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-1.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-1.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-10.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-10.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-100.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-100.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-101.png, error: cannot identify image file '/content/LoRA/train_data/._rum-101.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-102.png, error: cannot identify image file '/content/LoRA/train_data/._rum-102.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-105.png, error: cannot identify image file '/content/LoRA/train_data/._rum-105.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-106.png, error: cannot identify image file '/content/LoRA/train_data/._rum-106.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-107.png, error: cannot identify image file '/content/LoRA/train_data/._rum-107.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-116.png, error: cannot identify image file '/content/LoRA/train_data/._rum-116.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-117.png, error: cannot identify image file '/content/LoRA/train_data/._rum-117.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-118.png, error: cannot identify image file '/content/LoRA/train_data/._rum-118.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-119.png, error: cannot identify image file '/content/LoRA/train_data/._rum-119.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-120.png, error: cannot identify image file '/content/LoRA/train_data/._rum-120.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-121.png, error: cannot identify image file '/content/LoRA/train_data/._rum-121.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-122.png, error: cannot identify image file '/content/LoRA/train_data/._rum-122.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-14.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-14.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-89.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-89.jpg'
#   9% 1/11 [00:00<00:01,  7.40it/s]Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-9.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-9.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-90.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-90.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-91.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-91.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-92.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-92.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-93.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-93.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-94.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-94.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-95.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-95.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-108.png, error: cannot identify image file '/content/LoRA/train_data/._rum-108.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-109.png, error: cannot identify image file '/content/LoRA/train_data/._rum-109.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-110.png, error: cannot identify image file '/content/LoRA/train_data/._rum-110.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-111.png, error: cannot identify image file '/content/LoRA/train_data/._rum-111.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-112.png, error: cannot identify image file '/content/LoRA/train_data/._rum-112.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-113.png, error: cannot identify image file '/content/LoRA/train_data/._rum-113.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-114.png, error: cannot identify image file '/content/LoRA/train_data/._rum-114.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-115.png, error: cannot identify image file '/content/LoRA/train_data/._rum-115.png'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-17.jpeg, error: cannot identify image file '/content/LoRA/train_data/._rum-17.jpeg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-2.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-2.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-3.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-3.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-5.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-5.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-6.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-6.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-8.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-8.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-86.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-86.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-88.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-88.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-96.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-96.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-97.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-97.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-98.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-98.jpg'
# Could not load image path / 画像を読み込めません: /content/LoRA/train_data/._rum-99.jpg, error: cannot identify image file '/content/LoRA/train_data/._rum-99.jpg'
#  55% 6/11 [00:00<00:00,  7.62it/s]
# /content/LoRA/train_data/rum-1.jpg:
#   Character tags:
#   General tags: looking at viewer, blue eyes, lying, no humans, animal, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-10.jpeg:
#   Character tags:
#   General tags: looking at viewer, lying, no humans, animal, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-100.jpg:
#   Character tags:
#   General tags: looking at viewer, no humans, bed, animal, cat, realistic, animal focus, white fur, whiskers
#
# /content/LoRA/train_data/rum-101.png:
#   Character tags:
#   General tags: looking at viewer, indoors, no humans, animal, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-102.png:
#   Character tags:
#   General tags: looking at viewer, indoors, no humans, animal, cat, realistic, blanket, under covers, animal focus
#
# /content/LoRA/train_data/rum-105.png:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, phone, cat, realistic, under covers, animal focus, whiskers
#
# /content/LoRA/train_data/rum-106.png:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, window, bed, animal, phone, cat, realistic, animal focus, whiskers
#
# /content/LoRA/train_data/rum-107.png:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, phone, border, cat, cellphone, realistic, animal focus, whiskers
#
# /content/LoRA/train_data/rum-108.png:
#   Character tags:
#   General tags: looking at viewer, lying, indoors, on back, pillow, no humans, bed, animal, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-109.png:
#   Character tags:
#   General tags: looking at viewer, no humans, bed, animal, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-110.png:
#   Character tags:
#   General tags: looking at viewer, holding, nail polish, no humans, animal, cat, out of frame, realistic, holding animal, animal focus, holding cat
#
# /content/LoRA/train_data/rum-111.png:
#   Character tags:
#   General tags: looking at viewer, holding, nail polish, animal, cat, out of frame, realistic, animal focus
#
# /content/LoRA/train_data/rum-112.png:
#   Character tags:
#   General tags: looking at viewer, holding, no humans, animal, cat, realistic, holding animal, animal focus, holding cat, reference inset, photo inset
#
# /content/LoRA/train_data/rum-113.png:
#   Character tags:
#   General tags: looking at viewer, no humans, animal, cat, box, realistic, animal focus
#
# /content/LoRA/train_data/rum-114.png:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, phone, cat, realistic, under covers, animal focus, whiskers
#
# /content/LoRA/train_data/rum-115.png:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, cat, realistic, under covers, animal focus, whiskers
#
# /content/LoRA/train_data/rum-116.png:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, phone, cat, cellphone, realistic, animal focus, whiskers
#
# /content/LoRA/train_data/rum-117.png:
#   Character tags:
#   General tags: looking at viewer, indoors, no humans, bed, animal, cat, realistic, animal focus, whiskers
#
# /content/LoRA/train_data/rum-118.png:
#   Character tags:
#   General tags: looking at viewer, blue eyes, indoors, no humans, bed, animal, cat, tiles, under covers, animal focus, tile wall
#
# /content/LoRA/train_data/rum-119.png:
#   Character tags:
#   General tags: looking at viewer, indoors, no humans, bed, animal, cat, realistic, tiles, under covers, animal focus, tile wall
#
# /content/LoRA/train_data/rum-120.png:
#   Character tags:
#   General tags: looking at viewer, no humans, animal, border, cat, blanket, under covers, animal focus
#
# /content/LoRA/train_data/rum-121.png:
#   Character tags:
#   General tags: looking at viewer, open mouth, holding, lying, no humans, animal, cat, animal focus
#
# /content/LoRA/train_data/rum-122.png:
#   Character tags:
#   General tags: looking at viewer, indoors, no humans, animal, table, cat, wooden floor, realistic, animal focus, whiskers
#
# /content/LoRA/train_data/rum-14.jpeg:
#   Character tags:
#   General tags: no humans, animal, cat, realistic, animal focus, white fur, whiskers, cat teaser
#
# /content/LoRA/train_data/rum-17.jpeg:
#   Character tags:
#   General tags: looking at viewer, green eyes, indoors, no humans, animal, cat, wooden floor, realistic, animal focus
#
# /content/LoRA/train_data/rum-2.jpg:
#   Character tags:
#   General tags: looking at viewer, no humans, animal, cat, realistic, animal focus, white fur
#
# /content/LoRA/train_data/rum-3.jpg:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, on bed, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-5.jpg:
#   Character tags:
#   General tags: looking at viewer, lying, no humans, animal, cat, close-up, colored sclera, realistic, animal focus
#
# /content/LoRA/train_data/rum-6.jpg:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, cat, realistic, under covers, animal focus, whiskers
#
# /content/LoRA/train_data/rum-8.jpg:
#   Character tags:
#   General tags: looking at viewer, green eyes, no humans, animal, cat, realistic, animal focus, whiskers
#
# /content/LoRA/train_data/rum-86.jpg:
#   Character tags:
#   General tags: looking at viewer, white background, green eyes, lying, on back, no humans, animal, cat, realistic, under covers, animal focus
#
# /content/LoRA/train_data/rum-88.jpg:
#   Character tags:
#   General tags: looking at viewer, no humans, animal, traditional media, cat, realistic, animal focus, whiskers
#
# /content/LoRA/train_data/rum-89.jpg:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, window, bed, animal, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-9.jpeg:
#   Character tags:
#   General tags: looking at viewer, green eyes, indoors, blurry, no humans, animal, cat, wooden floor, realistic, animal focus, photo background
#
# /content/LoRA/train_data/rum-90.jpg:
#   Character tags:
#   General tags: looking at viewer, indoors, no humans, bed, animal, cat, realistic, animal focus
#
# /content/LoRA/train_data/rum-91.jpg:
#   Character tags:
#   General tags: no humans, animal, cat, realistic, animal focus, white fur
#
# /content/LoRA/train_data/rum-92.jpg:
#   Character tags:
#   General tags: looking at viewer, indoors, pillow, no humans, bed, animal, cat, animal focus, rubber duck
#
# /content/LoRA/train_data/rum-93.jpg:
#   Character tags:
#   General tags: grey background, no humans, animal, cat, realistic, animal focus, white fur, whiskers
#
# /content/LoRA/train_data/rum-94.jpg:
#   Character tags:
#   General tags: looking at viewer, indoors, no humans, animal, cat, animal focus
#
# /content/LoRA/train_data/rum-95.jpg:
#   Character tags:
#   General tags: looking at viewer, grey background, no humans, bird, animal, stuffed toy, cat, stuffed animal, rabbit, animal focus, chick, duck, hamster
# 100% 11/11 [00:10<00:00,  1.10it/s]
#
# /content/LoRA/train_data/rum-96.jpg:
#   Character tags:
#   General tags: looking at viewer, no humans, animal, cat, animal focus, oversized animal
#
# /content/LoRA/train_data/rum-97.jpg:
#   Character tags:
#   General tags: looking at viewer, blurry, pillow, no humans, animal, cat, close-up, realistic, animal focus, white fur, whiskers
#
# /content/LoRA/train_data/rum-98.jpg:
#   Character tags:
#   General tags: looking at viewer, no humans, animal, traditional media, cat, realistic, animal focus, white fur, whiskers
#
# /content/LoRA/train_data/rum-99.jpg:
#   Character tags:
#   General tags: looking at viewer, no humans, animal, cat, realistic, animal focus, whiskers
# done!

# %%
# @title ### 4.2.3. Custom Caption/Tag
import os

# %store -r

os.chdir(root_dir)

# @markdown Add or remove custom tags here. You can refer to this [cheatsheet](https://rentry.org/kohyaminiguide#c-custom-tagscaption) for more information.
extension = ".txt"  # @param [".txt", ".caption"]
custom_tag = ""  # @param {type:"string"}
# @markdown Use `sub_folder` option to specify a subfolder for multi-concept training.
# @markdown > Specify `--all` to process all subfolders/`recursive`
sub_folder = "" #@param {type: "string"}
# @markdown Enable this to append custom tags at the end of lines.
append = False  # @param {type:"boolean"}
# @markdown Enable this if you want to remove captions/tags instead.
remove_tag = False  # @param {type:"boolean"}
recursive = False

if sub_folder == "":
    image_dir = train_data_dir
elif sub_folder == "--all":
    image_dir = train_data_dir
    recursive = True
elif sub_folder.startswith("/content"):
    image_dir = sub_folder
else:
    image_dir = os.path.join(train_data_dir, sub_folder)
    os.makedirs(image_dir, exist_ok=True)

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

def process_tags(filename, custom_tag, append, remove_tag):
    contents = read_file(filename)
    tags = [tag.strip() for tag in contents.split(',')]
    custom_tags = [tag.strip() for tag in custom_tag.split(',')]

    for custom_tag in custom_tags:
        custom_tag = custom_tag.replace("_", " ")
        if remove_tag:
            while custom_tag in tags:
                tags.remove(custom_tag)
        else:
            if custom_tag not in tags:
                if append:
                    tags.append(custom_tag)
                else:
                    tags.insert(0, custom_tag)

    contents = ', '.join(tags)
    write_file(filename, contents)

def process_directory(image_dir, tag, append, remove_tag, recursive):
    for filename in os.listdir(image_dir):
        file_path = os.path.join(image_dir, filename)

        if os.path.isdir(file_path) and recursive:
            process_directory(file_path, tag, append, remove_tag, recursive)
        elif filename.endswith(extension):
            process_tags(file_path, tag, append, remove_tag)

tag = custom_tag

if not any(
    [filename.endswith(extension) for filename in os.listdir(image_dir)]
):
    for filename in os.listdir(image_dir):
        if filename.endswith((".png", ".jpg", ".jpeg", ".webp", ".bmp")):
            open(
                os.path.join(image_dir, filename.split(".")[0] + extension),
                "w",
            ).close()

if custom_tag:
    process_directory(image_dir, tag, append, remove_tag, recursive)

# %% [markdown]
# # V. Training Model

# %%
# @title ## 5.1. Model Config
from google.colab import drive

v2 = False  # @param {type:"boolean"}
v_parameterization = False  # @param {type:"boolean"}
project_name = "pretty-cat-rum-sama"  # @param {type:"string"}
if not project_name:
    project_name = "last"
# %store project_name
pretrained_model_name_or_path = "/content/drive/MyDrive/Lora_rum_sama/Model/v1-5-pruned-emaonly.safetensors"  # @param {type:"string"}
vae = ""  # @param {type:"string"}
output_dir = "/content/LoRA/output"  # @param {'type':'string'}

# @markdown `output_to_drive` sets default `output_dir` to `/content/drive/MyDrive/LoRA/output`. This will override the `output_dir` variable defined above.
output_to_drive = True  # @param {'type':'boolean'}

if output_to_drive:
    output_dir = "/content/drive/MyDrive/LoRA/output"

    if not os.path.exists("/content/drive"):
        drive.mount("/content/drive")

sample_dir = os.path.join(output_dir, "sample")
for dir in [output_dir, sample_dir]:
    os.makedirs(dir, exist_ok=True)

print("Project Name: ", project_name)
print("Model Version: Stable Diffusion V1.x") if not v2 else ""
print("Model Version: Stable Diffusion V2.x") if v2 and not v_parameterization else ""
print("Model Version: Stable Diffusion V2.x 768v") if v2 and v_parameterization else ""
print(
    "Pretrained Model Path: ", pretrained_model_name_or_path
) if pretrained_model_name_or_path else print("No Pretrained Model path specified.")
print("VAE Path: ", vae) if vae else print("No VAE path specified.")
print("Output Path: ", output_dir)
# Out:
# Stored 'project_name' (str)
# Project Name:  pretty-cat-rum-sama
# Model Version: Stable Diffusion V1.x
# Pretrained Model Path:  /content/drive/MyDrive/Lora_rum_sama/Model/v1-5-pruned-emaonly.safetensors
# No VAE path specified.
# Output Path:  /content/drive/MyDrive/LoRA/output

# %%
# @title ## 5.2. Dataset Config
import os
import toml
import glob

dataset_repeats = 10  # @param {type:"number"}
# @markdown `activation_word` is not used in training if you train with captions/tags, but it is still printed to metadata.
activation_word = "mksks"  # @param {type:"string"}
caption_extension = ".txt"  # @param ["none", ".txt", ".caption"]
# @markdown Please refer to `4.2.3. Custom Caption/Tag (Optional)` if you want to append `activation_word` to captions/tags
resolution = 512  # @param {type:"slider", min:512, max:1024, step:128}
flip_aug = False  # @param {type:"boolean"}
keep_tokens = 0  # @param {type:"number"}

def parse_folder_name(folder_name, default_num_repeats, default_class_token):
    folder_name_parts = folder_name.split("_")

    if len(folder_name_parts) == 2:
        if folder_name_parts[0].isdigit():
            num_repeats = int(folder_name_parts[0])
            class_token = folder_name_parts[1].replace("_", " ")
        else:
            num_repeats = default_num_repeats
            class_token = default_class_token
    else:
        num_repeats = default_num_repeats
        class_token = default_class_token

    return num_repeats, class_token

def find_image_files(path):
    supported_extensions = (".png", ".jpg", ".jpeg", ".webp", ".bmp")
    return [file for file in glob.glob(path + '/**/*', recursive=True) if file.lower().endswith(supported_extensions)]

def process_data_dir(data_dir, default_num_repeats, default_class_token, is_reg=False):
    subsets = []

    images = find_image_files(data_dir)
    if images:
        subsets.append({
            "image_dir": data_dir,
            "class_tokens": default_class_token,
            "num_repeats": default_num_repeats,
            **({"is_reg": is_reg} if is_reg else {}),
        })

    for root, dirs, files in os.walk(data_dir):
        for folder in dirs:
            folder_path = os.path.join(root, folder)
            images = find_image_files(folder_path)

            if images:
                num_repeats, class_token = parse_folder_name(folder, default_num_repeats, default_class_token)

                subset = {
                    "image_dir": folder_path,
                    "class_tokens": class_token,
                    "num_repeats": num_repeats,
                }

                if is_reg:
                    subset["is_reg"] = True

                subsets.append(subset)

    return subsets


train_subsets = process_data_dir(train_data_dir, dataset_repeats, activation_word)
reg_subsets = process_data_dir(reg_data_dir, dataset_repeats, activation_word, is_reg=True)

subsets = train_subsets + reg_subsets

config = {
    "general": {
        "enable_bucket": True,
        "caption_extension": caption_extension,
        "shuffle_caption": True,
        "keep_tokens": keep_tokens,
        "bucket_reso_steps": 64,
        "bucket_no_upscale": False,
    },
    "datasets": [
        {
            "resolution": resolution,
            "min_bucket_reso": 320 if resolution > 640 else 256,
            "max_bucket_reso": 1280 if resolution > 640 else 1024,
            "caption_dropout_rate": 0,
            "caption_tag_dropout_rate": 0,
            "caption_dropout_every_n_epochs": 0,
            "flip_aug": flip_aug,
            "color_aug": False,
            "face_crop_aug_range": None,
            "subsets": subsets,
        }
    ],
}

dataset_config = os.path.join(config_dir, "dataset_config.toml")

for key in config:
    if isinstance(config[key], dict):
        for sub_key in config[key]:
            if config[key][sub_key] == "":
                config[key][sub_key] = None
    elif config[key] == "":
        config[key] = None

config_str = toml.dumps(config)

with open(dataset_config, "w") as f:
    f.write(config_str)

print(config_str)
# Out:
# [[datasets]]
# resolution = 512
# min_bucket_reso = 256
# max_bucket_reso = 1024
# caption_dropout_rate = 0
# caption_tag_dropout_rate = 0
# caption_dropout_every_n_epochs = 0
# flip_aug = false
# color_aug = false
# [[datasets.subsets]]
# image_dir = "/content/LoRA/train_data"
# class_tokens = "mksks"
# num_repeats = 10
#
#
# [general]
# enable_bucket = true
# caption_extension = ".txt"
# shuffle_caption = true
# keep_tokens = 0
# bucket_reso_steps = 64
# bucket_no_upscale = false

# %%
# @title ## 5.3. LoRA and Optimizer Config

# @markdown ### LoRA Config:
network_category = "LoRA"  # @param ["LoRA", "LoCon", "LoCon_Lycoris", "LoHa"]

# @markdown Recommended values:

# @markdown | network_category | network_dim | network_alpha | conv_dim | conv_alpha |
# @markdown | :---: | :---: | :---: | :---: | :---: |
# @markdown | LoRA | 32 | 1 | - | - |
# @markdown | LoCon | 16 | 8 | 8 | 1 |
# @markdown | LoHa | 8 | 4 | 4 | 1 |

# @markdown - Note that `dropout` and `cp_decomposition` are not available in this notebook.

# @markdown `conv_dim` and `conv_alpha` are needed to train `LoCon` and `LoHa`; skip them if you are training normal `LoRA`. However, when in doubt, set `dim = alpha`.
conv_dim = 32  # @param {'type':'number'}
conv_alpha = 16  # @param {'type':'number'}
# @markdown It's recommended not to set `network_dim` and `network_alpha` higher than 64, especially for `LoHa`.
# @markdown If you want to use a higher value for `dim` or `alpha`, consider using a higher learning rate, as models with higher dimensions tend to learn faster.
network_dim = 32  # @param {'type':'number'}
network_alpha = 16  # @param {'type':'number'}
# @markdown You can specify this field for resume training.
network_weight = ""  # @param {'type':'string'}
network_module = "lycoris.kohya" if network_category in ["LoHa", "LoCon_Lycoris"] else "networks.lora"
network_args = "" if network_category == "LoRA" else [
    f"conv_dim={conv_dim}", f"conv_alpha={conv_alpha}",
    ]
# @markdown ### <br>Optimizer Config:
# @markdown `NEW` Gamma for reducing the weight of high-loss timesteps. Lower numbers have a stronger effect. The paper recommends 5. Read the paper [here](https://arxiv.org/abs/2303.09556).
min_snr_gamma = -1 #@param {type:"number"}
# @markdown `AdamW8bit` was the old `--use_8bit_adam`.
optimizer_type = "AdamW8bit"  # @param ["AdamW", "AdamW8bit", "Lion", "SGDNesterov", "SGDNesterov8bit", "DAdaptation", "AdaFactor"]
# @markdown Additional arguments for optimizer, e.g: `["decouple=True","weight_decay=0.6"]`
optimizer_args = ""  # @param {'type':'string'}
# @markdown Set `unet_lr` to `1.0` if you use `DAdaptation` optimizer, because it's a [free learning rate](https://github.com/facebookresearch/dadaptation) algorithm.
# @markdown However, it is recommended to set `text_encoder_lr = 0.5 * unet_lr`.
# @markdown Also, you don't need to specify `learning_rate` value if both `unet_lr` and `text_encoder_lr` are defined.
train_unet = True  # @param {'type':'boolean'}
unet_lr = 1e-4  # @param {'type':'number'}
train_text_encoder = True  # @param {'type':'boolean'}
text_encoder_lr = 5e-5  # @param {'type':'number'}
lr_scheduler = "constant"  # @param ["linear", "cosine", "cosine_with_restarts", "polynomial", "constant", "constant_with_warmup", "adafactor"] {allow-input: false}
lr_warmup_steps = 0  # @param {'type':'number'}
# @markdown You can define `num_cycles` value for `cosine_with_restarts` or `power` value for `polynomial` in the field below.
lr_scheduler_num_cycles = 0  # @param {'type':'number'}
lr_scheduler_power = 0  # @param {'type':'number'}

if network_category == "LoHa":
  network_args.append("algo=loha")
elif network_category == "LoCon_Lycoris":
  network_args.append("algo=lora")

print("- LoRA Config:")
print(f"  - Min-SNR Weighting: {min_snr_gamma}") if not min_snr_gamma == -1 else ""
print(f"  - Loading network module: {network_module}")
if not network_category == "LoRA":
  print(f"  - network args: {network_args}")
print(f"  - {network_module} linear_dim set to: {network_dim}")
print(f"  - {network_module} linear_alpha set to: {network_alpha}")
if not network_category == "LoRA":
  print(f"  - {network_module} conv_dim set to: {conv_dim}")
  print(f"  - {network_module} conv_alpha set to: {conv_alpha}")

if not network_weight:
    print("  - No LoRA weight loaded.")
else:
    if os.path.exists(network_weight):
        print(f"  - Loading LoRA weight: {network_weight}")
    else:
        print(f"  - {network_weight} does not exist.")
        network_weight = ""

print("- Optimizer Config:")
print(f"  - Additional network category: {network_category}")
print(f"  - Using {optimizer_type} as Optimizer")
if optimizer_args:
    print(f"  - Optimizer Args: {optimizer_args}")
if train_unet and train_text_encoder:
    print("  - Train UNet and Text Encoder")
    print(f"    - UNet learning rate: {unet_lr}")
    print(f"    - Text encoder learning rate: {text_encoder_lr}")
if train_unet and not train_text_encoder:
    print("  - Train UNet only")
    print(f"    - UNet learning rate: {unet_lr}")
if train_text_encoder and not train_unet:
    print("  - Train Text Encoder only")
    print(f"    - Text encoder learning rate: {text_encoder_lr}")
print(f"  - Learning rate warmup steps: {lr_warmup_steps}")
print(f"  - Learning rate Scheduler: {lr_scheduler}")
if lr_scheduler == "cosine_with_restarts":
    print(f"  - lr_scheduler_num_cycles: {lr_scheduler_num_cycles}")
elif lr_scheduler == "polynomial":
    print(f"  - lr_scheduler_power: {lr_scheduler_power}")
# Out:
# - LoRA Config:
#   - Loading network module: networks.lora
#   - networks.lora linear_dim set to: 32
#   - networks.lora linear_alpha set to: 16
#   - No LoRA weight loaded.
# - Optimizer Config:
#   - Additional network category: LoRA
#   - Using AdamW8bit as Optimizer
#   - Train UNet and Text Encoder
#     - UNet learning rate: 0.0001
#     - Text encoder learning rate: 5e-05
#   - Learning rate warmup steps: 0
#   - Learning rate Scheduler: constant

# %%
# @title ## 5.4. Training Config

import toml
import os

# %store -r
lowram = True  # @param {type:"boolean"}
enable_sample_prompt = True  # @param {type:"boolean"}
sampler = "ddim"  # @param ["ddim", "pndm", "lms", "euler", "euler_a", "heun", "dpm_2", "dpm_2_a", "dpmsolver","dpmsolver++", "dpmsingle", "k_lms", "k_euler", "k_euler_a", "k_dpm_2", "k_dpm_2_a"]
noise_offset = 0.0  # @param {type:"number"}
num_epochs = 10  # @param {type:"number"}
vae_batch_size = 4  # @param {type:"number"}
train_batch_size = 6  # @param {type:"number"}
mixed_precision = "fp16"  # @param ["no","fp16","bf16"] {allow-input: false}
save_precision = "fp16"  # @param ["float", "fp16", "bf16"] {allow-input: false}
save_n_epochs_type = "save_every_n_epochs"  # @param ["save_every_n_epochs", "save_n_epoch_ratio"] {allow-input: false}
save_n_epochs_type_value = 1  # @param {type:"number"}
save_model_as = "safetensors"  # @param ["ckpt", "pt", "safetensors"] {allow-input: false}
max_token_length = 225  # @param {type:"number"}
clip_skip = 2  # @param {type:"number"}
gradient_checkpointing = False  # @param {type:"boolean"}
gradient_accumulation_steps = 1  # @param {type:"number"}
seed = -1  # @param {type:"number"}
logging_dir = "/content/LoRA/logs"
prior_loss_weight = 1.0

os.chdir(repo_dir)

sample_str = f"""
  masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt \
  --n lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry \
  --w 512 \
  --h 768 \
  --l 7 \
  --s 28
"""

config = {
    "model_arguments": {
        "v2": v2,
        "v_parameterization": v_parameterization if v2 and v_parameterization else False,
        "pretrained_model_name_or_path": pretrained_model_name_or_path,
        "vae": vae,
    },
    "additional_network_arguments": {
        "no_metadata": False,
        "unet_lr": float(unet_lr) if train_unet else None,
        "text_encoder_lr": float(text_encoder_lr) if train_text_encoder else None,
        "network_weights": network_weight,
        "network_module": network_module,
        "network_dim": network_dim,
        "network_alpha": network_alpha,
        "network_args": network_args,
        "network_train_unet_only": True if train_unet and not train_text_encoder else False,
        "network_train_text_encoder_only": True if train_text_encoder and not train_unet else False,
        "training_comment": None,
    },
    "optimizer_arguments": {
        "min_snr_gamma": min_snr_gamma if not min_snr_gamma == -1 else None,
        "optimizer_type": optimizer_type,
        "learning_rate": unet_lr,
        "max_grad_norm": 1.0,
        "optimizer_args": eval(optimizer_args) if optimizer_args else None,
        "lr_scheduler": lr_scheduler,
        "lr_warmup_steps": lr_warmup_steps,
        "lr_scheduler_num_cycles": lr_scheduler_num_cycles if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power": lr_scheduler_power if lr_scheduler == "polynomial" else None,
    },
    "dataset_arguments": {
        "cache_latents": True,
        "debug_dataset": False,
        "vae_batch_size": vae_batch_size,
    },
    "training_arguments": {
        "output_dir": output_dir,
        "output_name": project_name,
        "save_precision": save_precision,
        "save_every_n_epochs": save_n_epochs_type_value if save_n_epochs_type == "save_every_n_epochs" else None,
        "save_n_epoch_ratio": save_n_epochs_type_value if save_n_epochs_type == "save_n_epoch_ratio" else None,
        "save_last_n_epochs": None,
        "save_state": None,
        "save_last_n_epochs_state": None,
        "resume": None,
        "train_batch_size": train_batch_size,
        "max_token_length": 225,
        "mem_eff_attn": False,
        "xformers": True,
        "max_train_epochs": num_epochs,
        "max_data_loader_n_workers": 8,
        "persistent_data_loader_workers": True,
        "seed": seed if seed > 0 else None,
        "gradient_checkpointing": gradient_checkpointing,
        "gradient_accumulation_steps": gradient_accumulation_steps,
        "mixed_precision": mixed_precision,
        "clip_skip": clip_skip if not v2 else None,
        "logging_dir": logging_dir,
        "log_prefix": project_name,
        "noise_offset": noise_offset if noise_offset > 0 else None,
        "lowram": lowram,
    },
    "sample_prompt_arguments": {
        "sample_every_n_steps": None,
        "sample_every_n_epochs": 1 if enable_sample_prompt else 999999,
        "sample_sampler": sampler,
    },
    "dreambooth_arguments": {
        "prior_loss_weight": 1.0,
    },
    "saving_arguments": {
        "save_model_as": save_model_as
    },
}

config_path = os.path.join(config_dir, "config_file.toml")
prompt_path = os.path.join(config_dir, "sample_prompt.txt")

for key in config:
    if isinstance(config[key], dict):
        for sub_key in config[key]:
            if config[key][sub_key] == "":
                config[key][sub_key] = None
    elif config[key] == "":
        config[key] = None

config_str = toml.dumps(config)

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

write_file(config_path, config_str)
write_file(prompt_path, sample_str)

print(config_str)
# Out:
# [model_arguments]
# v2 = false
# v_parameterization = false
# pretrained_model_name_or_path = "/content/drive/MyDrive/Lora_rum_sama/Model/v1-5-pruned-emaonly.safetensors"
#
# [additional_network_arguments]
# no_metadata = false
# unet_lr = 0.0001
# text_encoder_lr = 5e-5
# network_module = "networks.lora"
# network_dim = 32
# network_alpha = 16
# network_train_unet_only = false
# network_train_text_encoder_only = false
#
# [optimizer_arguments]
# optimizer_type = "AdamW8bit"
# learning_rate = 0.0001
# max_grad_norm = 1.0
# lr_scheduler = "constant"
# lr_warmup_steps = 0
#
# [dataset_arguments]
# cache_latents = true
# debug_dataset = false
# vae_batch_size = 4
#
# [training_arguments]
# output_dir = "/content/drive/MyDrive/LoRA/output"
# output_name = "pretty-cat-rum-sama"
# save_precision = "fp16"
# save_every_n_epochs = 1
# train_batch_size = 6
# max_token_length = 225
# mem_eff_attn = false
# xformers = true
# max_train_epochs = 10
# max_data_loader_n_workers = 8
# persistent_data_loader_workers = true
# gradient_checkpointing = false
# gradient_accumulation_steps = 1
# mixed_precision = "fp16"
# clip_skip = 2
# logging_dir = "/content/LoRA/logs"
# log_prefix = "pretty-cat-rum-sama"
# lowram = true
#
# [sample_prompt_arguments]
# sample_every_n_epochs = 1
# sample_sampler = "ddim"
#
# [dreambooth_arguments]
# prior_loss_weight = 1.0
#
# [saving_arguments]
# save_model_as = "safetensors"

# %%
#@title ## 5.5. Start Training

#@markdown Check your config here if you want to edit something:
#@markdown - `sample_prompt` : /content/LoRA/config/sample_prompt.txt
#@markdown - `config_file` : /content/LoRA/config/config_file.toml
#@markdown - `dataset_config` : /content/LoRA/config/dataset_config.toml

#@markdown Generated sample can be seen here: /content/LoRA/output/sample

#@markdown You can import config from another session if you want.
sample_prompt = "/content/LoRA/config/sample_prompt.txt" #@param {type:'string'}
config_file = "/content/LoRA/config/config_file.toml" #@param {type:'string'}
dataset_config = "/content/LoRA/config/dataset_config.toml" #@param {type:'string'}

accelerate_conf = {
    "config_file" : accelerate_config,
    "num_cpu_threads_per_process" : 1,
}

train_conf = {
    "sample_prompts" : sample_prompt,
    "dataset_config" : dataset_config,
    "config_file" : config_file
}

def train(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    return args

accelerate_args = train(accelerate_conf)
train_args = train(train_conf)
final_args = f"accelerate launch {accelerate_args} train_network.py {train_args}"

os.chdir(repo_dir)
# !{final_args}
# Out:
# Loading settings from /content/LoRA/config/config_file.toml...
# /content/LoRA/config/config_file
# prepare tokenizer
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:00<00:00, 83.4MB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 54.8MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 2.31MB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 4.97MB/s]
# update token length: 225
# Load dataset config from /content/LoRA/config/dataset_config.toml
# prepare images.
# found directory /content/LoRA/train_data contains 44 image files
# 440 train images with repeating.
# 0 reg images.
# no regularization images / 正則化画像が見つかりませんでした
# [Dataset 0]
#   batch_size: 6
#   resolution: (512, 512)
#   enable_bucket: True
#   min_bucket_reso: 256
#   max_bucket_reso: 1024
#   bucket_reso_steps: 64
#   bucket_no_upscale: False
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/LoRA/train_data"
#     image_count: 44
#     num_repeats: 10
#     shuffle_caption: True
#     keep_tokens: 0
#     caption_dropout_rate: 0
#     caption_dropout_every_n_epoches: 0
#     caption_tag_dropout_rate: 0
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1,
#     token_warmup_step: 0,
#     is_reg: False
#     class_tokens: mksks
#     caption_extension: .txt
#
#
# [Dataset 0]
# loading image sizes.
# 100% 44/44 [00:00<00:00, 2736.74it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (384, 640), count: 10
# bucket 1: resolution (448, 576), count: 250
# bucket 2: resolution (512, 512), count: 170
# bucket 3: resolution (576, 448), count: 10
# mean ar error (without repeats): 0.028723015247457573
# prepare accelerator
# Using accelerator 0.15.0 or above.
# loading model for process 0/1
# load StableDiffusion checkpoint
# loading u-net: <All keys matched successfully>
# loading vae: <All keys matched successfully>
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 15.8MB/s]
# Downloading pytorch_model.bin: 100% 1.71G/1.71G [00:11<00:00, 144MB/s]
# loading text encoder: <All keys matched successfully>
# Replace CrossAttention.forward to use xformers
# [Dataset 0]
# caching latents.
# 100% 14/14 [00:15<00:00,  1.12s/it]
# import network module: networks.lora
# create LoRA network. base dim (rank): 32, alpha: 16
# create LoRA for Text Encoder: 72 modules.
# create LoRA for U-Net: 192 modules.
# enable LoRA for text encoder
# enable LoRA for U-Net
# prepare optimizer, data loader etc.
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# use 8-bit AdamW optimizer | {}
# override steps. steps for 10 epochs is / 指定エポックまでのステップ数: 750
# running training / 学習開始
#   num train images * repeats / 学習画像の数×繰り返し回数: 440
#   num reg images / 正則化画像の数: 0
#   num batches per epoch / 1epochのバッチ数: 75
#   num epochs / epoch数: 10
#   batch size per device / バッチサイズ: 6
#   gradient accumulation steps / 勾配を合計するステップ数 = 1
#   total optimization steps / 学習ステップ数: 750
# steps:   0% 0/750 [00:00<?, ?it/s]epoch 1/10
# steps:  10% 75/750 [01:43<15:33,  1.38s/it, loss=0.138]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000001.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 75
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:11,  2.27it/s]
#   7% 2/28 [00:00<00:09,  2.85it/s]
#  11% 3/28 [00:01<00:08,  3.06it/s]
#  14% 4/28 [00:01<00:07,  3.16it/s]
#  18% 5/28 [00:01<00:07,  3.23it/s]
#  21% 6/28 [00:01<00:06,  3.28it/s]
#  25% 7/28 [00:02<00:06,  3.31it/s]
#  29% 8/28 [00:02<00:06,  3.33it/s]
#  32% 9/28 [00:02<00:05,  3.34it/s]
#  36% 10/28 [00:03<00:05,  3.35it/s]
#  39% 11/28 [00:03<00:05,  3.36it/s]
#  43% 12/28 [00:03<00:04,  3.36it/s]
#  46% 13/28 [00:04<00:04,  3.36it/s]
#  50% 14/28 [00:04<00:04,  3.35it/s]
#  54% 15/28 [00:04<00:03,  3.35it/s]
#  57% 16/28 [00:04<00:03,  3.36it/s]
#  61% 17/28 [00:05<00:03,  3.36it/s]
#  64% 18/28 [00:05<00:02,  3.37it/s]
#  68% 19/28 [00:05<00:02,  3.37it/s]
#  71% 20/28 [00:06<00:02,  3.37it/s]
#  75% 21/28 [00:06<00:02,  3.37it/s]
#  79% 22/28 [00:06<00:01,  3.37it/s]
#  82% 23/28 [00:06<00:01,  3.36it/s]
#  86% 24/28 [00:07<00:01,  3.38it/s]
#  89% 25/28 [00:07<00:00,  3.37it/s]
#  93% 26/28 [00:07<00:00,  3.37it/s]
#  96% 27/28 [00:08<00:00,  3.37it/s]
# 100% 28/28 [00:08<00:00,  3.31it/s]
# epoch 2/10
# steps:  20% 150/750 [03:36<14:27,  1.45s/it, loss=0.151]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000002.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 150
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.44it/s]
#   7% 2/28 [00:00<00:07,  3.29it/s]
#  11% 3/28 [00:00<00:07,  3.29it/s]
#  14% 4/28 [00:01<00:07,  3.30it/s]
#  18% 5/28 [00:01<00:06,  3.34it/s]
#  21% 6/28 [00:01<00:06,  3.35it/s]
#  25% 7/28 [00:02<00:06,  3.35it/s]
#  29% 8/28 [00:02<00:05,  3.35it/s]
#  32% 9/28 [00:02<00:05,  3.36it/s]
#  36% 10/28 [00:02<00:05,  3.35it/s]
#  39% 11/28 [00:03<00:05,  3.36it/s]
#  43% 12/28 [00:03<00:04,  3.36it/s]
#  46% 13/28 [00:03<00:04,  3.36it/s]
#  50% 14/28 [00:04<00:04,  3.36it/s]
#  54% 15/28 [00:04<00:03,  3.37it/s]
#  57% 16/28 [00:04<00:03,  3.36it/s]
#  61% 17/28 [00:05<00:03,  3.35it/s]
#  64% 18/28 [00:05<00:02,  3.36it/s]
#  68% 19/28 [00:05<00:02,  3.36it/s]
#  71% 20/28 [00:05<00:02,  3.36it/s]
#  75% 21/28 [00:06<00:02,  3.35it/s]
#  79% 22/28 [00:06<00:01,  3.36it/s]
#  82% 23/28 [00:06<00:01,  3.36it/s]
#  86% 24/28 [00:07<00:01,  3.35it/s]
#  89% 25/28 [00:07<00:00,  3.36it/s]
#  93% 26/28 [00:07<00:00,  3.36it/s]
#  96% 27/28 [00:08<00:00,  3.36it/s]
# 100% 28/28 [00:08<00:00,  3.35it/s]
# epoch 3/10
# steps:  30% 225/750 [05:29<12:49,  1.47s/it, loss=0.138]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000003.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 225
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.45it/s]
#   7% 2/28 [00:00<00:07,  3.42it/s]
#  11% 3/28 [00:00<00:07,  3.38it/s]
#  14% 4/28 [00:01<00:07,  3.37it/s]
#  18% 5/28 [00:01<00:06,  3.37it/s]
#  21% 6/28 [00:01<00:06,  3.38it/s]
#  25% 7/28 [00:02<00:06,  3.36it/s]
#  29% 8/28 [00:02<00:05,  3.36it/s]
#  32% 9/28 [00:02<00:05,  3.36it/s]
#  36% 10/28 [00:02<00:05,  3.35it/s]
#  39% 11/28 [00:03<00:05,  3.36it/s]
#  43% 12/28 [00:03<00:04,  3.36it/s]
#  46% 13/28 [00:03<00:04,  3.35it/s]
#  50% 14/28 [00:04<00:04,  3.36it/s]
#  54% 15/28 [00:04<00:03,  3.36it/s]
#  57% 16/28 [00:04<00:03,  3.35it/s]
#  61% 17/28 [00:05<00:03,  3.36it/s]
#  64% 18/28 [00:05<00:02,  3.36it/s]
#  68% 19/28 [00:05<00:02,  3.36it/s]
#  71% 20/28 [00:05<00:02,  3.36it/s]
#  75% 21/28 [00:06<00:02,  3.36it/s]
#  79% 22/28 [00:06<00:01,  3.35it/s]
#  82% 23/28 [00:06<00:01,  3.35it/s]
#  86% 24/28 [00:07<00:01,  3.35it/s]
#  89% 25/28 [00:07<00:00,  3.36it/s]
#  93% 26/28 [00:07<00:00,  3.35it/s]
#  96% 27/28 [00:08<00:00,  3.35it/s]
# 100% 28/28 [00:08<00:00,  3.36it/s]
# epoch 4/10
# steps:  40% 300/750 [07:22<11:03,  1.47s/it, loss=0.13]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000004.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 300
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.44it/s]
#   7% 2/28 [00:00<00:07,  3.41it/s]
#  11% 3/28 [00:00<00:07,  3.36it/s]
#  14% 4/28 [00:01<00:07,  3.36it/s]
#  18% 5/28 [00:01<00:06,  3.37it/s]
#  21% 6/28 [00:01<00:06,  3.38it/s]
#  25% 7/28 [00:02<00:06,  3.35it/s]
#  29% 8/28 [00:02<00:05,  3.36it/s]
#  32% 9/28 [00:02<00:05,  3.36it/s]
#  36% 10/28 [00:02<00:05,  3.36it/s]
#  39% 11/28 [00:03<00:05,  3.36it/s]
#  43% 12/28 [00:03<00:04,  3.37it/s]
#  46% 13/28 [00:03<00:04,  3.37it/s]
#  50% 14/28 [00:04<00:04,  3.37it/s]
#  54% 15/28 [00:04<00:03,  3.36it/s]
#  57% 16/28 [00:04<00:03,  3.37it/s]
#  61% 17/28 [00:05<00:03,  3.36it/s]
#  64% 18/28 [00:05<00:02,  3.36it/s]
#  68% 19/28 [00:05<00:02,  3.36it/s]
#  71% 20/28 [00:05<00:02,  3.36it/s]
#  75% 21/28 [00:06<00:02,  3.36it/s]
#  79% 22/28 [00:06<00:01,  3.36it/s]
#  82% 23/28 [00:06<00:01,  3.35it/s]
#  86% 24/28 [00:07<00:01,  3.36it/s]
#  89% 25/28 [00:07<00:00,  3.36it/s]
#  93% 26/28 [00:07<00:00,  3.36it/s]
#  96% 27/28 [00:08<00:00,  3.35it/s]
# 100% 28/28 [00:08<00:00,  3.36it/s]
# epoch 5/10
# steps:  50% 375/750 [09:14<09:14,  1.48s/it, loss=0.147]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000005.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 375
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.46it/s]
#   7% 2/28 [00:00<00:07,  3.40it/s]
#  11% 3/28 [00:00<00:07,  3.39it/s]
#  14% 4/28 [00:01<00:07,  3.37it/s]
#  18% 5/28 [00:01<00:06,  3.37it/s]
#  21% 6/28 [00:01<00:06,  3.38it/s]
#  25% 7/28 [00:02<00:06,  3.36it/s]
#  29% 8/28 [00:02<00:05,  3.36it/s]
#  32% 9/28 [00:02<00:05,  3.36it/s]
#  36% 10/28 [00:02<00:05,  3.35it/s]
#  39% 11/28 [00:03<00:05,  3.36it/s]
#  43% 12/28 [00:03<00:04,  3.36it/s]
#  46% 13/28 [00:03<00:04,  3.35it/s]
#  50% 14/28 [00:04<00:04,  3.36it/s]
#  54% 15/28 [00:04<00:03,  3.36it/s]
#  57% 16/28 [00:04<00:03,  3.36it/s]
#  61% 17/28 [00:05<00:03,  3.35it/s]
#  64% 18/28 [00:05<00:02,  3.36it/s]
#  68% 19/28 [00:05<00:02,  3.36it/s]
#  71% 20/28 [00:05<00:02,  3.35it/s]
#  75% 21/28 [00:06<00:02,  3.36it/s]
#  79% 22/28 [00:06<00:01,  3.36it/s]
#  82% 23/28 [00:06<00:01,  3.36it/s]
#  86% 24/28 [00:07<00:01,  3.35it/s]
#  89% 25/28 [00:07<00:00,  3.36it/s]
#  93% 26/28 [00:07<00:00,  3.36it/s]
#  96% 27/28 [00:08<00:00,  3.36it/s]
# 100% 28/28 [00:08<00:00,  3.36it/s]
# epoch 6/10
# steps:  60% 450/750 [11:06<07:24,  1.48s/it, loss=0.142]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000006.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 450
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.44it/s]
#   7% 2/28 [00:00<00:07,  3.40it/s]
#  11% 3/28 [00:00<00:07,  3.37it/s]
#  14% 4/28 [00:01<00:07,  3.36it/s]
#  18% 5/28 [00:01<00:06,  3.37it/s]
#  21% 6/28 [00:01<00:06,  3.37it/s]
#  25% 7/28 [00:02<00:06,  3.34it/s]
#  29% 8/28 [00:02<00:05,  3.35it/s]
#  32% 9/28 [00:02<00:05,  3.36it/s]
#  36% 10/28 [00:02<00:05,  3.34it/s]
#  39% 11/28 [00:03<00:05,  3.33it/s]
#  43% 12/28 [00:03<00:04,  3.35it/s]
#  46% 13/28 [00:03<00:04,  3.35it/s]
#  50% 14/28 [00:04<00:04,  3.34it/s]
#  54% 15/28 [00:04<00:03,  3.34it/s]
#  57% 16/28 [00:04<00:03,  3.36it/s]
#  61% 17/28 [00:05<00:03,  3.35it/s]
#  64% 18/28 [00:05<00:02,  3.33it/s]
#  68% 19/28 [00:05<00:02,  3.34it/s]
#  71% 20/28 [00:05<00:02,  3.35it/s]
#  75% 21/28 [00:06<00:02,  3.34it/s]
#  79% 22/28 [00:06<00:01,  3.34it/s]
#  82% 23/28 [00:06<00:01,  3.34it/s]
#  86% 24/28 [00:07<00:01,  3.34it/s]
#  89% 25/28 [00:07<00:00,  3.35it/s]
#  93% 26/28 [00:07<00:00,  3.35it/s]
#  96% 27/28 [00:08<00:00,  3.35it/s]
# 100% 28/28 [00:08<00:00,  3.35it/s]
# epoch 7/10
# steps:  70% 525/750 [13:00<05:34,  1.49s/it, loss=0.132]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000007.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 525
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.43it/s]
#   7% 2/28 [00:00<00:07,  3.41it/s]
#  11% 3/28 [00:00<00:07,  3.37it/s]
#  14% 4/28 [00:01<00:07,  3.36it/s]
#  18% 5/28 [00:01<00:06,  3.37it/s]
#  21% 6/28 [00:01<00:06,  3.38it/s]
#  25% 7/28 [00:02<00:06,  3.35it/s]
#  29% 8/28 [00:02<00:05,  3.36it/s]
#  32% 9/28 [00:02<00:05,  3.35it/s]
#  36% 10/28 [00:02<00:05,  3.35it/s]
#  39% 11/28 [00:03<00:05,  3.36it/s]
#  43% 12/28 [00:03<00:04,  3.36it/s]
#  46% 13/28 [00:03<00:04,  3.37it/s]
#  50% 14/28 [00:04<00:04,  3.36it/s]
#  54% 15/28 [00:04<00:03,  3.35it/s]
#  57% 16/28 [00:04<00:03,  3.35it/s]
#  61% 17/28 [00:05<00:03,  3.36it/s]
#  64% 18/28 [00:05<00:02,  3.36it/s]
#  68% 19/28 [00:05<00:02,  3.36it/s]
#  71% 20/28 [00:05<00:02,  3.36it/s]
#  75% 21/28 [00:06<00:02,  3.36it/s]
#  79% 22/28 [00:06<00:01,  3.36it/s]
#  82% 23/28 [00:06<00:01,  3.36it/s]
#  86% 24/28 [00:07<00:01,  3.36it/s]
#  89% 25/28 [00:07<00:00,  3.36it/s]
#  93% 26/28 [00:07<00:00,  3.36it/s]
#  96% 27/28 [00:08<00:00,  3.37it/s]
# 100% 28/28 [00:08<00:00,  3.36it/s]
# epoch 8/10
# steps:  80% 600/750 [14:52<03:43,  1.49s/it, loss=0.124]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000008.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 600
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.46it/s]
#   7% 2/28 [00:00<00:07,  3.40it/s]
#  11% 3/28 [00:00<00:07,  3.37it/s]
#  14% 4/28 [00:01<00:07,  3.36it/s]
#  18% 5/28 [00:01<00:06,  3.36it/s]
#  21% 6/28 [00:01<00:06,  3.36it/s]
#  25% 7/28 [00:02<00:06,  3.35it/s]
#  29% 8/28 [00:02<00:05,  3.36it/s]
#  32% 9/28 [00:02<00:05,  3.36it/s]
#  36% 10/28 [00:02<00:05,  3.35it/s]
#  39% 11/28 [00:03<00:05,  3.36it/s]
#  43% 12/28 [00:03<00:04,  3.36it/s]
#  46% 13/28 [00:03<00:04,  3.36it/s]
#  50% 14/28 [00:04<00:04,  3.34it/s]
#  54% 15/28 [00:04<00:03,  3.35it/s]
#  57% 16/28 [00:04<00:03,  3.36it/s]
#  61% 17/28 [00:05<00:03,  3.35it/s]
#  64% 18/28 [00:05<00:02,  3.34it/s]
#  68% 19/28 [00:05<00:02,  3.36it/s]
#  71% 20/28 [00:05<00:02,  3.35it/s]
#  75% 21/28 [00:06<00:02,  3.33it/s]
#  79% 22/28 [00:06<00:01,  3.34it/s]
#  82% 23/28 [00:06<00:01,  3.35it/s]
#  86% 24/28 [00:07<00:01,  3.35it/s]
#  89% 25/28 [00:07<00:00,  3.35it/s]
#  93% 26/28 [00:07<00:00,  3.35it/s]
#  96% 27/28 [00:08<00:00,  3.36it/s]
# 100% 28/28 [00:08<00:00,  3.35it/s]
# epoch 9/10
# steps:  90% 675/750 [16:45<01:51,  1.49s/it, loss=0.126]saving checkpoint: /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama-000009.safetensors
# generating sample images at step / サンプル画像生成 ステップ: 675
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.44it/s]
#   7% 2/28 [00:00<00:07,  3.42it/s]
#  11% 3/28 [00:00<00:07,  3.36it/s]
#  14% 4/28 [00:01<00:07,  3.35it/s]
#  18% 5/28 [00:01<00:06,  3.35it/s]
#  21% 6/28 [00:01<00:06,  3.36it/s]
#  25% 7/28 [00:02<00:06,  3.35it/s]
#  29% 8/28 [00:02<00:05,  3.35it/s]
#  32% 9/28 [00:02<00:05,  3.36it/s]
#  36% 10/28 [00:02<00:05,  3.35it/s]
#  39% 11/28 [00:03<00:05,  3.35it/s]
#  43% 12/28 [00:03<00:04,  3.35it/s]
#  46% 13/28 [00:03<00:04,  3.35it/s]
#  50% 14/28 [00:04<00:04,  3.35it/s]
#  54% 15/28 [00:04<00:03,  3.34it/s]
#  57% 16/28 [00:04<00:03,  3.33it/s]
#  61% 17/28 [00:05<00:03,  3.34it/s]
#  64% 18/28 [00:05<00:02,  3.35it/s]
#  68% 19/28 [00:05<00:02,  3.35it/s]
#  71% 20/28 [00:05<00:02,  3.34it/s]
#  75% 21/28 [00:06<00:02,  3.34it/s]
#  79% 22/28 [00:06<00:01,  3.35it/s]
#  82% 23/28 [00:06<00:01,  3.34it/s]
#  86% 24/28 [00:07<00:01,  3.34it/s]
#  89% 25/28 [00:07<00:00,  3.34it/s]
#  93% 26/28 [00:07<00:00,  3.35it/s]
#  96% 27/28 [00:08<00:00,  3.35it/s]
# 100% 28/28 [00:08<00:00,  3.35it/s]
# epoch 10/10
# steps: 100% 750/750 [18:37<00:00,  1.49s/it, loss=0.13] generating sample images at step / サンプル画像生成 ステップ: 750
# prompt: masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt
# negative_prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry
# height: 768
# width: 512
# sample_steps: 28
# scale: 7.0
#
#   0% 0/28 [00:00<?, ?it/s]
#   4% 1/28 [00:00<00:07,  3.42it/s]
#   7% 2/28 [00:00<00:07,  3.40it/s]
#  11% 3/28 [00:00<00:07,  3.35it/s]
#  14% 4/28 [00:01<00:07,  3.34it/s]
#  18% 5/28 [00:01<00:06,  3.35it/s]
#  21% 6/28 [00:01<00:06,  3.34it/s]
#  25% 7/28 [00:02<00:06,  3.33it/s]
#  29% 8/28 [00:02<00:05,  3.35it/s]
#  32% 9/28 [00:02<00:05,  3.35it/s]
#  36% 10/28 [00:02<00:05,  3.33it/s]
#  39% 11/28 [00:03<00:05,  3.34it/s]
#  43% 12/28 [00:03<00:04,  3.35it/s]
#  46% 13/28 [00:03<00:04,  3.36it/s]
#  50% 14/28 [00:04<00:04,  3.34it/s]
#  54% 15/28 [00:04<00:03,  3.34it/s]
#  57% 16/28 [00:04<00:03,  3.35it/s]
#  61% 17/28 [00:05<00:03,  3.35it/s]
#  64% 18/28 [00:05<00:02,  3.35it/s]
#  68% 19/28 [00:05<00:02,  3.35it/s]
#  71% 20/28 [00:05<00:02,  3.35it/s]
#  75% 21/28 [00:06<00:02,  3.35it/s]
#  79% 22/28 [00:06<00:01,  3.34it/s]
#  82% 23/28 [00:06<00:01,  3.34it/s]
#  86% 24/28 [00:07<00:01,  3.33it/s]
#  89% 25/28 [00:07<00:00,  3.32it/s]
#  93% 26/28 [00:07<00:00,  3.32it/s]
#  96% 27/28 [00:08<00:00,  3.34it/s]
# 100% 28/28 [00:08<00:00,  3.34it/s]
# save trained model to /content/drive/MyDrive/LoRA/output/pretty-cat-rum-sama.safetensors
# model saved.
# steps: 100% 750/750 [18:47<00:00,  1.50s/it, loss=0.13]

# %%
# 学習に使用した画像のプロンプトを確認する
# !cat /content/LoRA/train_data/*.txt
# Out:
# looking at viewer, no humans, bed, animal, cat, realistic, animal focus, white fur, whiskers
# looking at viewer, indoors, no humans, animal, cat, realistic, animal focus
# looking at viewer, indoors, no humans, animal, cat, realistic, blanket, under covers, animal focus
# looking at viewer, indoors, pillow, no humans, bed, animal, phone, cat, realistic, under covers, animal focus, whiskers
# looking at viewer, indoors, pillow, no humans, window, bed, animal, phone, cat, realistic, animal focus, whiskers
# looking at viewer, indoors, pillow, no humans, bed, animal, phone, border, cat, cellphone, realistic, animal focus, whiskers
# looking at viewer, lying, indoors, on back, pillow, no humans, bed, animal, cat, realistic, animal focus
# looking at viewer, no humans, bed, animal, cat, realistic, animal focus
# looking at viewer, lying, no humans, animal, cat, realistic, animal focus
# looking at viewer, holding, nail polish, no humans, animal, cat, out of frame, realistic, holding animal, animal focus, holding cat
# looking at viewer, holding, nail polish, animal, cat, out of frame, realistic, animal focus
# looking at viewer, holding, no humans, animal, cat, realistic, holding animal, animal focus, holding cat, reference inset, photo inset
# looking at viewer, no humans, animal, cat, box, realistic, animal focus
# looking at viewer, indoors, pillow, no humans, bed, animal, phone, cat, realistic, under covers, animal focus, whiskers
# looking at viewer, indoors, pillow, no humans, bed, animal, cat, realistic, under covers, animal focus, whiskers
# looking at viewer, indoors, pillow, no humans, bed, animal, phone, cat, cellphone, realistic, animal focus, whiskers
# looking at viewer, indoors, no humans, bed, animal, cat, realistic, animal focus, whiskers
# looking at viewer, blue eyes, indoors, no humans, bed, animal, cat, tiles, under covers, animal focus, tile wall
# looking at viewer, indoors, no humans, bed, animal, cat, realistic, tiles, under covers, animal focus, tile wall
# looking at viewer, no humans, animal, border, cat, blanket, under covers, animal focus
# looking at viewer, open mouth, holding, lying, no humans, animal, cat, animal focus
# looking at viewer, indoors, no humans, animal, table, cat, wooden floor, realistic, animal focus, whiskers
# no humans, animal, cat, realistic, animal focus, white fur, whiskers, cat teaser
# looking at viewer, green eyes, indoors, no humans, animal, cat, wooden floor, realistic, animal focus
# looking at viewer, blue eyes, lying, no humans, animal, cat, realistic, animal focus
# looking at viewer, no humans, animal, cat, realistic, animal focus, white fur
# looking at viewer, indoors, pillow, no humans, bed, animal, on bed, cat, realistic, animal focus
# looking at viewer, lying, no humans, animal, cat, close-up, colored sclera, realistic, animal focus
# looking at viewer, indoors, pillow, no humans, bed, animal, cat, realistic, under covers, animal focus, whiskers
# looking at viewer, white background, green eyes, lying, on back, no humans, animal, cat, realistic, under covers, animal focus
# looking at viewer, no humans, animal, traditional media, cat, realistic, animal focus, whiskers
# looking at viewer, indoors, pillow, no humans, window, bed, animal, cat, realistic, animal focus
# looking at viewer, green eyes, no humans, animal, cat, realistic, animal focus, whiskers
# looking at viewer, indoors, no humans, bed, animal, cat, realistic, animal focus
# no humans, animal, cat, realistic, animal focus, white fur
# looking at viewer, indoors, pillow, no humans, bed, animal, cat, animal focus, rubber duck
# grey background, no humans, animal, cat, realistic, animal focus, white fur, whiskers
# looking at viewer, indoors, no humans, animal, cat, animal focus
# looking at viewer, grey background, no humans, bird, animal, stuffed toy, cat, stuffed animal, rabbit, animal focus, chick, duck, hamster
# looking at viewer, no humans, animal, cat, animal focus, oversized animal
# looking at viewer, blurry, pillow, no humans, animal, cat, close-up, realistic, animal focus, white fur, whiskers
# looking at viewer, no humans, animal, traditional media, cat, realistic, animal focus, white fur, whiskers
# looking at viewer, no humans, animal, cat, realistic, animal focus, whiskers
# looking at viewer, green eyes, indoors, blurry, no humans, animal, cat, wooden floor, realistic, animal focus, photo background
